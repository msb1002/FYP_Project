# %%
# !sh basics.sh
# Out:
# .9.0-py38hecd8cb5_0
#   anaconda-project   pkgs/main/noarch::anaconda-project-0.10.2-pyhd3eb1b0_0
#   anyio              pkgs/main/osx-64::anyio-2.2.0-py38hecd8cb5_1
#   appdirs            pkgs/main/noarch::appdirs-1.4.4-pyhd3eb1b0_0
#   applaunchservices  pkgs/main/noarch::applaunchservices-0.2.1-pyhd3eb1b0_0
#   appscript          pkgs/main/osx-64::appscript-1.1.2-py38h9ed2024_0
#   argh               pkgs/main/osx-64::argh-0.26.2-py38_0
#   arrow              pkgs/main/osx-64::arrow-0.13.1-py38_0
#   asn1crypto         pkgs/main/noarch::asn1crypto-1.4.0-py_0
#   astroid            pkgs/main/osx-64::astroid-2.6.6-py38hecd8cb5_0
#   astropy            pkgs/main/osx-64::astropy-5.0-py38h7588534_0
#   atomicwrites       pkgs/main/noarch::atomicwrites-1.4.0-py_0
#   autopep8           pkgs/main/noarch::autopep8-1.6.0-pyhd3eb1b0_0
#   babel              pkgs/main/noarch::babel-2.9.1-pyhd3eb1b0_0
#   backports          pkgs/main/noarch::backports-1.1-pyhd3eb1b0_0
# ...

# %%
# %run models.py
# Out:
# All Iibraries Imported!

# %%
# %run data_imports.py

# %%
#Print the database for the implementations
df = process()
additional_features(df)
df.head()
# Out:
# Enter the code of the model that you want to implement
# Loading the dataset for the MSFT
#        Open      High     Low   Close    Volume      10_sma      20_sma  \
# 1  306.2900  313.9093  302.70  303.33  45933855  302.465000  302.465000
# 2  304.0700  309.8000  301.74  302.65  42434112  302.526667  302.526667
# 3  304.2500  310.8200  303.75  310.20  39846414  304.445000  304.445000
# 4  320.4658  320.8800  304.00  304.80  45365979  304.516000  304.516000
# 5  319.6700  323.4100  317.08  318.27  34372217  306.808333  306.808333
#
#        50_sma      10_ema      20_ema      50_ema  bollinger_mean  \
# 1  302.465000  302.551500  302.508250  302.482300      302.465000
# 2  302.526667  302.591096  302.560300  302.540451      302.526667
# 3  304.445000  305.097891  304.765763  304.571732      304.445000
# 4  304.516000  305.012375  304.774045  304.621109      304.516000
# 5  306.808333  308.455838  307.621075  307.129344      306.808333
#
# ...

# %%
# %run svr.py

# %%
svr_func(df)
# Out:
# Pure prediction section
# Actual score - poly
# 0.7243597001525823
# Actual score - rbf
# 0.9867086410047495
# ------------------------------------
# SVR SVR(C=1000.0, degree=2, kernel='poly') PERFORMANCE
# r2 score: 0.7243597001525823
# RMSE : 41.58540229789617
# Mean Absolute Error : 31.17600215552987
# SVR SVR(C=1000.0, gamma=0.15) PERFORMANCE
# r2 score: 0.9867086410047495
# RMSE : 9.131754862053016
# Mean Absolute Error : 3.9034675030180983

# %%
svm_func(df)
# Out:
# Momentum prediction - as classifier
# Prediction score for poly SVM classifier :  0.5753968253968254
# Prediction score for RBF SVM classifier :  0.5753968253968254

# %%
# %run DNN.py

# %%
dnn(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/zq/smmq3w090flfzkg3_666vkh80000gn/T/ipykernel_25778/3479403147.py in <module>
# ----> 1 dnn(df)
#
# ~/Desktop/FYP HKUST/Codes/DNN.py in dnn(df)
#      25     model = keras.Sequential(
#      26         [
# ---> 27             layers.Dense(64, activation="relu", input_shape=(len(X.columns),)),
#      28             layers.Dense(128, activation="relu", name="layer1"),
#      29             layers.Dense(256, activation="relu", name="layer2"),
#
# NameError: name 'layers' is not defined
