# %% [markdown]
# <a href="https://colab.research.google.com/github/msb1002/FYP_Project/blob/master/Traditional_backtesting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 0. Basic

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
volatility_folder = "/content/drive/MyDrive/fyp/Final report/4. Backtesting/Volatility_result/"
backtest_summary_folder = volatility_folder + "backtest_summary/"
record_folder = volatility_folder + "trade_record/"
user_test_folder = volatility_folder + "user_test/"
model_folder = "/content/drive/MyDrive/fyp/Final report/4. Backtesting/XGBoost/"

# %%
def convert_prediction(X,y,pred):

    col_list =[] 
    for col in X.columns:
        if "open" in col:
            col_list.append(col)
    mean_5_day = np.mean(X.loc[:,col_list],axis=1)
    mean_5_day.index = y.index
    std_5_day = np.std(X.loc[:,col_list],axis=1)
    std_5_day.index = y.index
    a = pd.DataFrame(index = y.index,columns=['mean','std','pred'])
    a.loc[:,"mean"] = mean_5_day
    a.loc[:,"std"] = std_5_day
    a.loc[:,"pred"] = pred
    a.loc[:,"converted"] = pred*std_5_day+mean_5_day
    return a["converted"]

# %%
def convert_decision(stock_,pred):
    h = np.array(pred)
    action = []
    status = "N"
    five_sma = stock_['open'].rolling(window=5,min_periods=1).mean()

    ind_sma = five_sma.index
    ind_pred = pred.index
    union_ind = list(ind_sma.intersection(ind_pred))

    five_sma = five_sma.filter(items = union_ind)
    pred = pred.filter(items = union_ind)

    for i in range(len(union_ind)):

        if pred.iloc[i] >= five_sma.iloc[i]:
            if status == "N":
                action.append("Buy")
                status = "Buy"
            else:
                action.append("Hold")
        else:
            if status == "Buy":
                action.append("Sell")
                status = "N"
            else:
                action.append("Hold")

    result = (pd.DataFrame(action,
                         columns=["Action"], index = pred.index))
                
    return result

# %% [markdown]
# #1. Library Import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from math import floor

import torch.nn as nn
import os.path as osp
import torch.utils.data as data
import torch.nn.functional as F

from tqdm import tqdm
import time, matplotlib, torch, os
from statsmodels.tsa.arima_model import ARIMA
from torch.utils.tensorboard import SummaryWriter

# %%
import os
from os import walk

import plotly
# %matplotlib inline
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from datetime import datetime
#import seaborn as sns

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
#For DNN / CNN+LSTM
import keras.backend as K
from keras.models import Sequential
from keras.layers import Conv1D, LSTM, Flatten, Dense

# %%
# !pip install -q stockstats

# %% [markdown]
# # Backtesting Setting

# %%
start_date = []
num_period = 10
period_year = 1

start = 2022-(num_period+period_year-1)
for i in range(num_period):
    start_date.append((start+i)*10000+101)


date_range_list={}
for i in start_date:
    date_range_list[i] = (i-101)+(period_year-1)*10000+1231

print(date_range_list)

stock_list = {"BlockChain":["COIN","NVDA","FB"],
              "Airline":["BA","GD","LMT",],
              "Traveling":["UBER","ABNB","MAR","BKNG"],
              "Semiconductors":["INTC","NVDA","QCOM","MU","AMD"],
              "Cloud Computing":["IBM", "AMZN","GOOG","CRM"],
              "Social Media":["TWTR","SNAP","PINS","FB"],
              "Entertainment":["DIS","NFLX","FB"],
              "Retail":["WMT","COST","TGT","BBY","HD"],
              "Franchise":["MCD", "YUM", "SBUX", "DPZ"],
              "Real Estate":["HST", "EQR", "AVB", "PLD", "SPG"],
              "Telecommunication":["T","TMUS","VZ","CMCSA","CHTR"],
              "Energy & Resources":["DOW", "DD"],
              "Luxury goods":["RACE","EL","PVH"]
                            }

#stock_list = {"Entertainment":["DIS","NFLX","FB"]}

start_date = "2000-01-01"
end_date = "2022-12-31"


do_nth_name = "Buy&Hold"
model_name = "WithModel"

backtest_col = ["Sector","Stock",
                "Range_Start","Range_End",
                do_nth_name+"_Profit",model_name+"_Profit",
                do_nth_name+"_CAGR(in %)",model_name+"_CAGR(in %)",
                "CAGR_Performance(in %)",
                do_nth_name+"_MDD(in %)",model_name+"_MDD(in %)",
                "MDD_Performance(in %)"]
# Out:
# {20120101: 20121231, 20130101: 20131231, 20140101: 20141231, 20150101: 20151231, 20160101: 20161231, 20170101: 20171231, 20180101: 20181231, 20190101: 20191231, 20200101: 20201231, 20210101: 20211231}

# %% [markdown]
# # Backtesting Module

# %%
################### Input ##########################
# For hist_price_data: index=["date"], columns = ["Open"]
# For pred_action: index=["date"], columns = ["Action"] (Buy/Sell)
################### Output #########################
# 1. trading record
# 2. total profit
class backtest:
    hpd = ""
    pred_action=pd.DataFrame()
    trade_record=pd.DataFrame(index=[],
                              columns=["Action","Price","Position","Cash","Pos_Bal","Cash_Bal","Cum_Profit","Total_Bal"],
                             )
    capital = 0
    cash_balance = 0
    profit = 0
    handle_fee = 0
    position = 0
    last_price = 0
    do_nth_profit = 0
    num_year = 0
    _tested = False
    
    _stock_trough = 0
    _stock_peak = 0
    _stock_all_time_low = 0
    _stock_all_time_high = 0
    
    _portfolio_trough = 0
    _portfolio_peak = 0
    _portfolio_all_time_low = 0
    _portfolio_all_time_high = 0
    
    def __init__(self,hist_price_data,pred_action,capital,handling_fee,num_year=1):
        self.hpd = hist_price_data
        self.pred_action = pred_action
        self.capital = capital
        self.cash_balance = capital
        self._portfolio_trough = capital
        self._portfolio_peak = capital
        self._portfolio_all_time_low = capital
        self._portfolio_all_time_high = capital
        self.handle_fee = handling_fee
        self.num_year = num_year  
        
    def clear_trade_record(self,sec):
        self.trade_record=pd.DataFrame(index=[],
                                       columns=["Action","Price","Position","Cash","Pos_Bal","Cash_Bal","Cum_Profit","Total_Bal"],
                                       )
        print("Clearing trade_record...")
        time.sleep(sec)
        
    def start_test(self): 
        if not self._tested:
            status = "sell"
            self._tested = True
            print("Start Backtesting...")  
            self._stock_all_time_low = self.hpd.iloc[0,0]
            self._stock_all_time_high = self.hpd.iloc[0,0]
            self._stock_trough = self.hpd.iloc[0,0]
            self._stock_peak = self.hpd.iloc[0,0]
            # For loop to iterate the data
            for ind in self.pred_action.index:
                # Update latest price
                self.last_price = self.hpd.loc[ind,"Open"]
                
                # Mark All Time Low,High , Trough and Peak for MDD of stock price (using "Buy&Hold")
                if self.last_price > self._stock_all_time_high:
                    self._stock_all_time_high = self.last_price
                if self.last_price < self._stock_all_time_low:
                    self._stock_all_time_low = self.last_price
                if self.last_price > self._stock_all_time_low and self._stock_trough != self._stock_all_time_low:
                    self._stock_trough = self._stock_all_time_low
                if self.last_price < self._stock_all_time_high and self._stock_peak != self._stock_all_time_high:
                    self._stock_peak = self._stock_all_time_high
                
                # Do the action
                if self.pred_action.loc[ind,"Action"].lower() == "buy" and status == "sell":
                    self._buy(ind,self.last_price)
                    status = "buy"
                elif self.pred_action.loc[ind,"Action"].lower() == "sell" and status == "buy":
                    self._sell(ind,self.last_price)
                    status = "sell"
                else:
                    self._hold(ind,self.last_price) # newly added
                    
                
                curr_portfolio_val = self.get_capital()+self.get_profit()
                
                # Mark All Time Low,High , Trough and Peak for MDD of our portfolio balance (using our model)
                if curr_portfolio_val > self._portfolio_all_time_high:
                    self._portfolio_all_time_high = curr_portfolio_val
                if curr_portfolio_val < self._portfolio_all_time_low:
                    self._portfolio_all_time_low = curr_portfolio_val
                if curr_portfolio_val > self._portfolio_all_time_low and self._portfolio_trough != self._portfolio_all_time_low:
                    self._portfolio_trough = self._portfolio_all_time_low
                if curr_portfolio_val < self._portfolio_all_time_high and self._portfolio_peak != self._portfolio_all_time_high:
                    self._portfolio_peak = self._portfolio_all_time_high
                            
            # =================================================
            self._run_do_nothing() # Calculate do nothing profit
        else:
            print("Backtesting has been completed...")
              
                
        
    def _mark_down_record(self,date,action,price,pos_delta,cash_delta):
        self.trade_record.loc[date] = [action,price,pos_delta,cash_delta,
                                       round(self.position,4),round(self.cash_balance,3),
                                       round(self.get_profit(),3),round(self.get_amount(),3)]
        
    def _buy(self,date,price):
        # Assume use all money to buy all
        buy_pos = floor(self.cash_balance / price)
        for i in range(buy_pos+1):
            act_buy_pos = buy_pos - i
            if act_buy_pos == 0:
                #print("You do not have enough money to buy!")
                return
            total_amt = act_buy_pos*price*(1+self.handle_fee)
            if self.cash_balance > total_amt:
                self.position += act_buy_pos
                self.cash_balance -= total_amt
                self._mark_down_record(date,
                                       "Buy",
                                       price,
                                       act_buy_pos,
                                       -total_amt)
                print("Bought at",date,"with price =", price, "\tPos:", act_buy_pos)
                return
        
    
    def _sell(self,date,price):
        # Assume sell all position
        sell_pos = self.position
        total_amt = sell_pos*price*(1-self.handle_fee)
        if self.position >= 1:
            self.position -= sell_pos
            self.cash_balance += total_amt
            self._mark_down_record(date,
                                   "Sell",
                                   price,
                                   -sell_pos,
                                   total_amt)
            print("Sold at",date,"with price =", price, "\tPos:", sell_pos)
            
            return
        
    def _hold(self,date,price): # newly added
        self._mark_down_record(date,"Hold",price,0,0)

    def _run_do_nothing(self):
        balance = self.capital
        first_day_price = self.hpd.iloc[0,0]
        last_day_price = self.hpd.iloc[-1,0]
        buy_pos = floor(self.capital / first_day_price) # Calculate how many position can buy
        total_amt = buy_pos*first_day_price*(1+self.handle_fee) # Check if okay to buy (including fee)
        while self.capital < total_amt: # If not enough, reduce buy_pos by 1
            buy_pos -= 1
            total_amt = buy_pos*first_day_price*(1+self.handle_fee)
        position = buy_pos # Buy in 
        balance -= total_amt
        self.do_nth_profit = last_day_price*position+balance-self.capital

    def get_performance(self):
        if self._tested:
            model_profit = self.get_profit()
            do_nth_profit = self.get_do_nothing()
            perf = (model_profit-do_nth_profit)/abs(do_nth_profit)
            return perf
        else:
            print("No Backtesting Record.")

    def get_do_nothing(self):
        if self._tested:
            return self.do_nth_profit
        else:
            print("No Backtesting Record.")

    def get_profit(self):
        if self._tested:
            return self.get_cash_balance()+self.get_last_price()*self.get_position()-self.get_capital()
        else:
            print("No Backtesting Record.")

    def get_last_price(self):
        if self._tested:
            return self.last_price
        else:
            print("No Backtesting Record.")
    
    def get_position(self):
        if self._tested:
            return self.position
        else:
            print("No Backtesting Record.")
    
    def get_do_nothing_CAGR(self):
        if self._tested:
            start_bal = self.get_capital()
            end_bal = self.get_do_nothing()+self.get_capital()
            num_year = self.get_num_year()
            return pow(end_bal/start_bal,1/num_year)-1
        else:
            print("No Backtesting Record.")
            
    def get_model_CAGR(self):
        if self._tested:
            start_bal = self.get_capital()
            end_bal = self.get_profit()+self.get_capital()
            num_year = self.get_num_year()
            return pow(end_bal/start_bal,1/num_year)-1
        else:
            print("No Backtesting Record.")
            
    def get_diff_in_CAGR(self):
        if self._tested:
            return self.get_model_CAGR() - self.get_do_nothing_CAGR()
        else:
            print("No Backtesting Record.")
    
    def get_do_nothing_MDD(self):
        if self._tested:
            return (self._stock_trough-self._stock_peak)/self._stock_peak
        else:
            print("No Backtesting Record.")
            
    def get_model_MDD(self):
        if self._tested:
            return (self._portfolio_trough-self._portfolio_peak)/self._portfolio_peak
        else:
            print("No Backtesting Record.")
            
    def get_diff_in_MDD(self):
        if self._tested:
            return self.get_model_MDD() - self.get_do_nothing_MDD()
        else:
            print("No Backtesting Record.")
    
    def get_num_year(self):
        return self.num_year
    
    def get_cash_balance(self):
        return self.cash_balance
    
    def get_capital(self):
        return self.capital
    
    def get_amount(self):
        return self.get_capital()+self.get_profit()

    def print_do_nothing(self):
        if self._tested:
            print("If buy at", self.hpd.index[0],"with price =",self.hpd.iloc[0,0])
            print("and do nothing")
            print("Current Profit:",self.get_do_nothing())
        else:
            print("No Backtesting Record.")
            
    def print_performance(self):
        if self._tested:
            print("Performance:", str(round(self.get_performance()*100,2))+"%")
        else:
            print("No Backtesting Record.")
            
    def print_CAGR_performance(self):
        if self._tested:
            print("CAGR Performance:", str(round(self.get_diff_in_CAGR()*100,2))+"%")
        else:
            print("No Backtesting Record.")
    
    def print_trade_record(self):
        if self._tested:
            print(self.trade_record)
        else:
            print("No Backtesting Record.")
            print(self.trade_record)
    
    def print_profit(self):
        if self._tested:
            print("Current Profit with model:",self.get_profit())
        else:
            print("No Backtesting Record.")
    
    def export_trade_record(self,stock,add_msg = ""):
        if self._tested:
            # Save the trade record to the path
            if not add_msg == "":
                add_msg = "_" + add_msg
            self.trade_record = self.trade_record.sort_index()
            self.trade_record.to_csv(record_folder+stock+add_msg+".csv")
            print("Trade record exported.")
        else:
            print("No Backtesting Record.")

# %%
def get_last_n_day_mean(df,n):
    series = df["open"]
    windows = series.rolling(n)
    n_days_averages = windows.mean()
    n_days_list = n_days_averages.tolist()
    final_list = n_days_list[n:]
    new_df = pd.DataFrame(final_list,columns=["mean_"+str(n)],index=df.index[n:])
    return new_df

# %% [markdown]
# # Load Data

# %%
import pandas_datareader.data as web
from stockstats import StockDataFrame

#Setting the index values as timestamp
def process(code):
  print("Enter the code of the model that you want to implement")
  #code = input()
  #final_code = '^'+code
  final_code = code
  start_date = "2012-01-01"
  end_date = "2021-12-31"
  stock = web.DataReader(final_code , 'stooq',start=start_date, end=end_date)
  stock.columns = ["open","high","low","close","volume"]
  
  # Use online package to generate additional features
  x = StockDataFrame(stock)
  stock = x[['open','high','low','close','volume',
          'boll', 'boll_ub', 'boll_lb',
          'macd', 'macdh', 'macds',
          'rsi_11', 'rsi_14', 'rsi_21']]
  stock.index = [int(str(ind)[0:4]+str(ind)[5:7]+str(ind)[8:10]) for ind in stock.index]
  stock = stock.sort_index()

  return stock

# %%
stock = process("IBM")
# Out:
# Enter the code of the model that you want to implement

# %%
stock
# Out:
#             open    high     low   close   volume      boll     boll_ub  \
# 20120103  128.88  130.23  128.38  128.58  8180058  128.1790  134.932612
# 20120104  128.10  128.60  127.63  128.07  6297526  128.3965  135.476771
# 20120105  127.56  127.71  126.38  127.46  6466200  128.6025  135.879775
# 20120106  127.28  127.34  125.83  125.98  7094969  128.9115  136.502568
# 20120109  125.76  125.80  124.42  125.33  7535572  129.2665  136.943913
# ...          ...     ...     ...     ...      ...       ...         ...
# 20211227  129.08  130.08  128.40  130.05  4346229  131.4500  133.282321
# 20211228  130.03  131.63  130.02  131.05  3488601  131.8000  132.899939
# 20211229  130.82  132.61  130.73  131.76  4291007  132.0500  132.611070
# 20211230  132.16  132.77  131.74  132.32  3196152  132.1950  132.548553
# 20211231  132.41  133.38  132.02  132.07  3402558  132.0700         NaN
#
#              boll_lb      macd     macdh     macds      rsi_11      rsi_14  \
# 20120103  121.425388 -1.811274  0.489102 -2.300376   51.281366   47.190995
# 20120104  121.316229 -2.091832  0.330819 -2.422652   48.488535   44.808561
# 20120105  121.325225 -2.367574  0.137783 -2.505356   45.064237   41.897279
# 20120106  121.320432 -2.622973 -0.083171 -2.539802   35.625325   34.061158
# 20120109  121.589087 -2.760113 -0.241104 -2.519009   30.883945   30.223364
# ...              ...       ...       ...       ...         ...         ...
# 20211227  129.617679 -0.099397 -0.058552 -0.040846    8.180361    8.545592
# 20211228  130.700061 -0.042801 -0.026749 -0.016052   14.491914   14.911940
# 20211229  131.488930 -0.010219 -0.007870 -0.002349   28.868360   29.305681
# 20211230  131.841447  0.005609  0.002493  0.003116  100.000000  100.000000
# 20211231         NaN  0.000000  0.000000  0.000000         NaN         NaN
#
#               rsi_21
# 20120103   42.920670
# 20120104   41.192557
# 20120105   39.091982
# 20120106   33.612565
# 20120109   31.016798
# ...              ...
# 20211227    8.997984
# 20211228   15.424720
# 20211229   29.832936
# 20211230  100.000000
# 20211231         NaN
#
# [2517 rows x 14 columns]

# %% [markdown]
# # Data preprocessing for regression models

# %% [markdown]
#  Split the train and test data - for IBM

# %%
# Split the train and test data
def custom_split(data,start,end):
    train = (data.index >= start) & (data.index <= end)
    train_X = data[train]
    
    return train_X

# %%
train_X = custom_split(stock,start = 20130101,end = 20171031)
valid_X = custom_split(stock,start = 20171101,end = 20181231)
test_X = custom_split(stock,start = 20190101,end = 20201231)

# %%
print(len(train_X))
print(len(valid_X))
print(len(test_X))
# Out:
# 1218
# 292
# 505

# %% [markdown]
# Label the target result (opening price on 11th day)

# %%
# Assume we use 10 days price data to predict closing price of the 11th day
num_day_to_predict = 5

# %%
def produce_result_target_price(X,num_day = 5,result_col_name = "result_price"):
    y = pd.DataFrame(np.nan, index=X.index, columns=[result_col_name])
    for i in range(5,len(X)):
        y.loc[X.index[i-1],result_col_name] = X.loc[X.index[i],"open"]
    
    return y

# %%
train_y = produce_result_target_price(train_X,num_day_to_predict)
valid_y = produce_result_target_price(valid_X,num_day_to_predict)
test_y = produce_result_target_price(test_X,num_day_to_predict)

# %%
print(len(train_y))
print(len(valid_y))
print(len(test_y))
# Out:
# 1218
# 292
# 505

# %%
pred_y = produce_result_target_price(stock,num_day_to_predict)

# %% [markdown]
# Transform the 10-day data into one vector

# %%
def transform_x_data_to_one_vector(X,num_day):
    col_name = []
    for i in range(num_day):
        for j in X.columns:
            col_name.append(j+"-"+str(i))
    new_X = pd.DataFrame(np.nan, index=X.index, columns=col_name)
    
    for i in range(num_day-1,len(X)):
        for col in col_name:
            split_list = col.split("-")
            new_X.loc[X.index[i],col] = X.loc[X.index[i-int(split_list[1])],split_list[0]]
    
    return new_X

# %%
train_X_5 = transform_x_data_to_one_vector(train_X,num_day_to_predict)
valid_X_5 = transform_x_data_to_one_vector(valid_X,num_day_to_predict)
test_X_5 = transform_x_data_to_one_vector(test_X,num_day_to_predict)

# %%
pred_X_5 = transform_x_data_to_one_vector(stock,num_day_to_predict)

# %%
print(len(train_X_5))
print(len(valid_X_5))
print(len(test_X_5))
print(len(pred_X_5))
# Out:
# 1218
# 292
# 505
# 2517

# %% [markdown]
#  Drop out rows with NaN

# %%
def drop_nan_row_y(y,num_day = 5):
    drop_list = [y.index[i] for i in range(num_day-1)]
    drop_list.append(y.index[-1])
    return y.drop(drop_list)

def drop_nan_row_X_5(X,num_day = 5):
    drop_list = [X.index[i] for i in range(num_day-1)]
    drop_list.append(X.index[-1])
    return X.drop(drop_list)

# %%
new_train_X_5 = drop_nan_row_X_5(train_X_5,num_day_to_predict)
new_train_y = drop_nan_row_y(train_y,num_day_to_predict)

new_valid_X_5  = drop_nan_row_X_5(valid_X_5,num_day_to_predict)
new_valid_y = drop_nan_row_y(valid_y,num_day_to_predict)

new_test_X_5  = drop_nan_row_X_5(test_X_5,num_day_to_predict)
new_test_y = drop_nan_row_y(test_y,num_day_to_predict)

# %%
new_pred_X_5  = drop_nan_row_X_5(pred_X_5,num_day_to_predict)
new_pred_y = drop_nan_row_y(pred_y,num_day_to_predict)

# %%
print(len(new_train_X_5))
print(len(new_valid_X_5))
print(len(new_test_X_5))
print(len(new_pred_X_5))
# Out:
# 1213
# 287
# 500
# 2512

# %%
print(len(new_train_y))
print(len(new_valid_y))
print(len(new_test_y))
print(len(new_pred_y))
# Out:
# 1213
# 287
# 500
# 2512

# %%
# Keep a copy for reverting prediction result
old_train_X_5 = new_train_X_5
old_train_y = new_train_y
old_valid_X_5 = new_valid_X_5
old_valid_y = new_valid_y
old_test_X_5 = new_test_X_5
old_test_y = new_test_y

# %%
old_pred_X_5 = new_pred_X_5
old_pred_y = new_pred_y

# %%
### Normalize data row by row

# %%
def normalize_data_by_row(X,y):
    norm_X = X.sub(X.mean(axis=0), axis=1).div(X.std(axis=0), axis=1)
    
    col_list =[] 
    for col in X.columns:
        if "open" in col:
            col_list.append(col)
    
    temp_y = y.loc[:,"result_price"]
    mean_5_day = np.mean(X.loc[:,col_list],axis=1)
    mean_5_day.index = temp_y.index
    std_5_day = np.std(X.loc[:,col_list],axis=1)
    std_5_day.index = temp_y.index
    

    norm_y = pd.DataFrame((temp_y-mean_5_day)/std_5_day,
                          columns=["result_price"])
                         
    return (norm_X,norm_y)

# %%
new_train_X_5,new_train_y = normalize_data_by_row(new_train_X_5,new_train_y)
new_valid_X_5,new_valid_y = normalize_data_by_row(new_valid_X_5,new_valid_y)
new_test_X_5,new_test_y = normalize_data_by_row(new_test_X_5,new_test_y)

# %%
new_pred_X_5,new_pred_y = normalize_data_by_row(new_pred_X_5,new_pred_y)

# %%
new_train_X_5 = drop_nan_row_X_5(new_train_X_5,num_day_to_predict)
new_valid_X_5 = drop_nan_row_X_5(new_valid_X_5,num_day_to_predict)
new_test_X_5 = drop_nan_row_X_5(new_test_X_5,num_day_to_predict)

# %%
new_train_y = drop_nan_row_y(new_train_y,num_day_to_predict)
new_valid_y = drop_nan_row_y(new_valid_y,num_day_to_predict)
new_test_y = drop_nan_row_y(new_test_y,num_day_to_predict)

# %%
len(new_test_X_5.columns)
# Out:
# 70

# %%
len(new_train_X_5)
#len(new_valid_X_5)
#len(new_test_X_5)
#len(new_pred_X_5)
# Out:
# 1208

# %% [markdown]
# # TWAP

# %% [markdown]
# ## process

# %%
def twap(df):
  opens = df.filter(like="open")
  closes = df.filter(like="close")
  highs = df.filter(like="high")
  lows = df.filter(like="low")
  return pd.concat([opens,closes,highs,lows],axis=1)

# %%
final_train = twap(new_train_X_5)
final_train.head()
# Out:
#             open-0    open-1    open-2    open-3    open-4   close-0  \
# 20130114  0.801829  0.850700  0.788361  0.838681  0.804244  0.785525
# 20130115  0.715955  0.800826  0.849662  0.787207  0.837732  0.780621
# 20130116  0.756030  0.714977  0.799804  0.848485  0.786275  0.784707
# 20130117  0.859896  0.755040  0.713982  0.798646  0.847534  0.846824
# 20130118  0.871346  0.858876  0.754032  0.712857  0.797710  0.895047
#
#            close-1   close-2   close-3   close-4    high-0    high-1  \
# 20130114  0.893255  0.799874  0.767687  0.797469  0.760783  0.855580
# 20130115  0.784580  0.892179  0.798716  0.766452  0.727228  0.759847
# 20130116  0.779677  0.783536  0.890988  0.797469  0.755054  0.726300
# 20130117  0.783763  0.778635  0.782385  0.889704  0.829532  0.754119
# 20130118  0.845863  0.782720  0.777485  0.781144  0.856540  0.828578
#
#             high-2    high-3    high-4     low-0     low-1     low-2  \
# 20130114  0.740043  0.770836  0.757528  0.804657  0.868912  0.775701
# 20130115  0.854563  0.738945  0.769790  0.725498  0.803646  0.867862
# 20130116  0.758857  0.853426  0.737910  0.781807  0.724510  0.802615
# 20130117  0.725319  0.757753  0.852349  0.890343  0.780802  0.723504
# 20130118  0.753131  0.724226  0.756711  0.921354  0.889308  0.779779
#
#              low-3     low-4
# 20130114  0.794957  0.791411
# 20130115  0.774575  0.793856
# 20130116  0.866701  0.773481
# 20130117  0.801479  0.865575
# 20130118  0.722397  0.800376

# %%
final_valid = twap(new_valid_X_5)

# %%
final_test = twap(new_test_X_5)

# %%
final_pred = twap(new_pred_X_5)

# %%
#df['TWAP'] = (df['Open']+df["Close"]+df["Low"]+df["High"]) / 4

for i in range(5):
  #df_ = final.filter(like=f"-{i}")
  final_train[f"TWAP_{i}"] = (final_train[f"open-{i}"]+final_train[f"open-{i}"]+final_train[f"open-{i}"]+final_train[f"open-{i}"])/4
  final_test[f"TWAP_{i}"] = (final_test[f"open-{i}"]+final_test[f"open-{i}"]+final_test[f"open-{i}"]+final_test[f"open-{i}"])/4
  final_valid[f"TWAP_{i}"] = (final_valid[f"open-{i}"]+final_valid[f"open-{i}"]+final_valid[f"open-{i}"]+final_valid[f"open-{i}"])/4
  final_pred[f"TWAP_{i}"] = (final_pred[f"open-{i}"]+final_pred[f"open-{i}"]+final_pred[f"open-{i}"]+final_pred[f"open-{i}"])/4

# %%
new_train_X_5 = final_train
new_test_X_5 = final_test 
new_valid_X_5 = final_valid
new_pred_X_5 = final_pred

# %%
"""
stock = "IBM"
print("Runninng stock: "+ stock)
stock_data_1 = web.DataReader(stock, "stooq",start=start_date, end=end_date)
stock_data_1.columns = ["open","high","low","close","volume"]
x_1 = StockDataFrame(stock_data_1)
print("entire dataset",len(x_1))
data_1 = x_1[['open','high','low','close','volume',
              'boll', 'boll_ub', 'boll_lb',
              'macd', 'macdh', 'macds',
              'rsi_11', 'rsi_14', 'rsi_21']]
data_1.index = [int(str(ind)[0:4]+str(ind)[5:7]+str(ind)[8:10]) for ind in data_1.index]
data_1 = data_1.sort_index()
print(stock + " Data loaded...")

for k,v in date_range_list.items():
    print(k,v)
    print("Getting Data... - " + stock + " from " + str(k))
    if (data_1.index[0]>v):
        print("No data for this testing period... - " + stock + " from " + str(k))
        continue
    test_X = custom_split(data_1,start = k,end = v)
    if len(test_X) <= num_day_to_predict:
        print("No enough data for testing... - " + stock + " from " + str(k))
        continue
        
    print("Transforming Data... - " + stock + " from " + str(k))
    test_y = produce_result_target_price(test_X,num_day_to_predict)
    test_X_5 = transform_x_data_to_one_vector(test_X,num_day_to_predict)
    new_test_X_5  = drop_nan_row_X_5(test_X_5,num_day_to_predict)
    new_test_y = drop_nan_row_y(test_y,num_day_to_predict)
    old_test_X_5 = new_test_X_5.copy()
    old_test_y = new_test_y.copy()
    new_test_X_5,new_test_y = normalize_data_by_row(new_test_X_5,new_test_y)

    final_train = twap(new_train_X_5)
    final_valid = twap(new_valid_X_5)
    final_test = twap(new_test_X_5)
    final_pred = twap(new_pred_X_5)

    for i in range(5):
      #df_ = final.filter(like=f"-{i}")
      final_train[f"TWAP_{i}"] = (final_train[f"open-{i}"]+final_train[f"open-{i}"]+final_train[f"open-{i}"]+final_train[f"open-{i}"])/4
      final_test[f"TWAP_{i}"] = (final_test[f"open-{i}"]+final_test[f"open-{i}"]+final_test[f"open-{i}"]+final_test[f"open-{i}"])/4
      final_valid[f"TWAP_{i}"] = (final_valid[f"open-{i}"]+final_valid[f"open-{i}"]+final_valid[f"open-{i}"]+final_valid[f"open-{i}"])/4
      final_pred[f"TWAP_{i}"] = (final_pred[f"open-{i}"]+final_pred[f"open-{i}"]+final_pred[f"open-{i}"]+final_pred[f"open-{i}"])/4


    new_train_X_5 = final_train
    new_test_X_5 = final_test 
    new_valid_X_5 = final_valid
    new_pred_X_5 = final_pred


    print("lengths of train,test,valid,pred",len(new_train_X_5),len(new_test_X_5),len(new_valid_X_5),len(new_pred_X_5))
    print("length of data_1 ", len(data_1))
    print("Predicting... - " + stock + " from " + str(k))
    twap_pred = twap_test.predict(new_test_X_5)

    print("input length",len(new_pred_X_5))
    print("gt train y length",len(new_pred_y))
    print("prediction length",len(twap_pred))
    
    print("Converting... - " + stock + " from " + str(k))
    pred_price = convert_prediction(old_test_X_5,old_test_y,twap_pred.flatten())

    data_copy = data_1
    print("data_copy length",len(data_copy))
    print("testing length",len(new_test_y),len(old_test_y))

    pred_action = convert_decision(data_copy,pred_price)
    final_test_y = old_test_y.rename(columns={"result_price":"Open"})
    #final_pred = final_pred.sort_index()

    print(len(pred_action),"pred_action")
    print(len(final_test_y),"final testing y")
    print(len(old_test_y))
    
    print("Backtesting... - " + stock + " from " + str(k))
    back1 = backtest(final_test_y,pred_action,10000,0.0005,period_year)
    back1.clear_trade_record(3)
    
    print("Start Iteration... - " + stock + " from " + str(k))
    back1.start_test()

    print("======= from "+ str(k) + " to " + str(v)+" =========")
    back1.print_do_nothing()
    back1.print_profit()
    back1.print_CAGR_performance()
    stock = ""
    stock = "TWAP_"+sector+"-"+stock
    msg_ = str(k)+"-to-"+str(v)+"("+str(round(back1.get_diff_in_CAGR()*100,2))+"%)"
    back1.export_trade_record(stock,msg_)
    backtest_summary = backtest_summary.append({"Sector":sector,
                                                "Stock":stock,
                                                "Range_Start":str(k),
                                                "Range_End":str(v),
                                                do_nth_name+"_Profit":round(back1.get_do_nothing(),2),
                                                model_name+"_Profit":round(back1.get_profit(),2),
                                                do_nth_name+"_CAGR(in %)":round(back1.get_do_nothing_CAGR()*100,2),
                                                model_name+"_CAGR(in %)":round(back1.get_model_CAGR()*100,2),
                                                "CAGR_Performance(in %)":round(back1.get_diff_in_CAGR()*100,2),
                                                do_nth_name+"_MDD(in %)":round(back1.get_do_nothing_MDD()*100,2),
                                                model_name+"_MDD(in %)":round(back1.get_model_MDD()*100,2),
                                                "MDD_Performance(in %)":round(back1.get_diff_in_MDD()*100,2)}, ignore_index=True)
    print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
    time.sleep(3)
"""
# Out:
# '\nstock = "IBM"\nprint("Runninng stock: "+ stock)\nstock_data_1 = web.DataReader(stock, "stooq",start=start_date, end=end_date)\nstock_data_1.columns = ["open","high","low","close","volume"]\nx_1 = StockDataFrame(stock_data_1)\nprint("entire dataset",len(x_1))\ndata_1 = x_1[[\'open\',\'high\',\'low\',\'close\',\'volume\',\n              \'boll\', \'boll_ub\', \'boll_lb\',\n              \'macd\', \'macdh\', \'macds\',\n              \'rsi_11\', \'rsi_14\', \'rsi_21\']]\ndata_1.index = [int(str(ind)[0:4]+str(ind)[5:7]+str(ind)[8:10]) for ind in data_1.index]\ndata_1 = data_1.sort_index()\nprint(stock + " Data loaded...")\n\nfor k,v in date_range_list.items():\n    print(k,v)\n    print("Getting Data... - " + stock + " from " + str(k))\n    if (data_1.index[0]>v):\n        print("No data for this testing period... - " + stock + " from " + str(k))\n        continue\n    test_X = custom_split(data_1,start = k,end = v)\n    if len(test_X) <= num_day_to_predict:\n        print("No enough data for testing... - " + stock + " from " + str(k))\n        continue\n        \n    print("Transforming Data... - " + stock + " from " + str(k))\n    test_y = produce_result_target_price(test_X,num_day_to_predict)\n    test_X_5 = transform_x_data_to_one_vector(test_X,num_day_to_predict)\n    new_test_X_5  = drop_nan_row_X_5(test_X_5,num_day_to_predict)\n    new_test_y = drop_nan_row_y(test_y,num_day_to_predict)\n    old_test_X_5 = new_test_X_5.copy()\n    old_test_y = new_test_y.copy()\n    new_test_X_5,new_test_y = normalize_data_by_row(new_test_X_5,new_test_y)\n\n    final_train = twap(new_train_X_5)\n    final_valid = twap(new_valid_X_5)\n    final_test = twap(new_test_X_5)\n    final_pred = twap(new_pred_X_5)\n\n    for i in range(5):\n      #df_ = final.filter(like=f"-{i}")\n      final_train[f"TWAP_{i}"] = (final_train[f"open-{i}"]+final_train[f"open-{i}"]+final_train[f"open-{i}"]+final_train[f"open-{i}"])/4\n      final_test[f"TWAP_{i}"] = (final_test[f"open-{i}"]+final_test[f"open-{i}"]+final_test[f"open-{i}"]+final_test[f"open-{i}"])/4\n      final_valid[f"TWAP_{i}"] = (final_valid[f"open-{i}"]+final_valid[f"open-{i}"]+final_valid[f"open-{i}"]+final_valid[f"open-{i}"])/4\n      final_pred[f"TWAP_{i}"] = (final_pred[f"open-{i}"]+final_pred[f"open-{i}"]+final_pred[f"open-{i}"]+final_pred[f"open-{i}"])/4\n\n\n    new_train_X_5 = final_train\n    new_test_X_5 = final_test \n    new_valid_X_5 = final_valid\n    new_pred_X_5 = final_pred\n\n\n    print("lengths of train,test,valid,pred",len(new_train_X_5),len(new_test_X_5),len(new_valid_X_5),len(new_pred_X_5))\n    print("length of data_1 ", len(data_1))\n    print("Predicting... - " + stock + " from " + str(k))\n    twap_pred = twap_test.predict(new_test_X_5)\n\n    print("input length",len(new_pred_X_5))\n    print("gt train y length",len(new_pred_y))\n    print("prediction length",len(twap_pred))\n    \n    print("Converting... - " + stock + " from " + str(k))\n    pred_price = convert_prediction(old_test_X_5,old_test_y,twap_pred.flatten())\n\n    data_copy = data_1\n    print("data_copy length",len(data_copy))\n    print("testing length",len(new_test_y),len(old_test_y))\n\n    pred_action = convert_decision(data_copy,pred_price)\n    final_test_y = old_test_y.rename(columns={"result_price":"Open"})\n    #final_pred = final_pred.sort_index()\n\n    print(len(pred_action),"pred_action")\n    print(len(final_test_y),"final testing y")\n    print(len(old_test_y))\n    \n    print("Backtesting... - " + stock + " from " + str(k))\n    back1 = backtest(final_test_y,pred_action,10000,0.0005,period_year)\n    back1.clear_trade_record(3)\n    \n    print("Start Iteration... - " + stock + " from " + str(k))\n    back1.start_test()\n\n    print("======= from "+ str(k) + " to " + str(v)+" =========")\n    back1.print_do_nothing()\n    back1.print_profit()\n    back1.print_CAGR_performance()\n    stock = ""\n    stock = "TWAP_"+sector+"-"+stock\n    msg_ = str(k)+"-to-"+str(v)+"("+str(round(back1.get_di ...

# %%
from tensorflow import keras
from tensorflow.keras import layers, callbacks

early_stopping = callbacks.EarlyStopping(
    min_delta=0.0001, # minimium change considered improvement
    patience=50, # how many epochs to wait before stopping
    restore_best_weights=True,
)

#train_X, test_X, train_y, test_y
model = keras.Sequential([
    layers.Dense(units=1024, input_shape=[len(new_train_X_5.columns)]),
    layers.Dropout(0.2),
    layers.BatchNormalization(),
    layers.Dense(512, activation='relu'),
    layers.Dropout(0.2),
    layers.BatchNormalization(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.2),
    layers.BatchNormalization(),
    layers.Dense(1)

])

model.compile(
    optimizer='adam',
    loss='mae',
)

history = model.fit(
    new_train_X_5, new_train_y,
    validation_data=(new_valid_X_5, new_valid_y),
    batch_size=256,
    epochs=200,
    callbacks=[early_stopping], # put your callbacks in a list
    verbose=False
)

# %%
pred_y = model.predict(new_test_X_5)

# %%
len(pred_y)
# Out:
# 495

# %%
#Performance evaluation
print('TWAP PERFORMANCE')
print('r2 score: '+str(r2_score(new_test_y, pred_y)))
print('RMSE : '+str(np.sqrt(mean_squared_error(new_test_y, pred_y))))
print("Mean Absolute Error : " + str(mean_absolute_error(new_test_y,pred_y)))
# Out:
# TWAP PERFORMANCE
# r2 score: 0.5922647145770852
# RMSE : 1.4384007950565656
# Mean Absolute Error : 0.9168193194462392

# %%
import pickle

# %%
cd //
# Out:
# /

# %%
cd content
# Out:
# /content

# %%
with open(model_folder+"TWAP.pickle", "wb") as f:
    pickle.dump(model, f)
# Out:
# INFO:tensorflow:Assets written to: ram://dc39a858-41f9-4f66-a9ee-6426f1efff6e/assets

# %%
x = model.predict(new_test_X_5)
len(x)

# %%
twap_final_pred = model.predict(new_pred_X_5)

# %%
len(new_pred_X_5)

# %%
twap_final_pred_converted = convert_prediction(old_pred_X_5,old_pred_y,twap_final_pred.flatten())
twap_final_pred_converted

# %%
stock

# %%
len(stock)

# %%
len(twap_final_pred_converted)

# %%
action_twap = convert_decision(stock,twap_final_pred_converted)
action_twap['pred_price'] = twap_final_pred_converted.tolist()

# %%
action_twap

# %%
cd /content/drive/MyDrive/fyp/'Final report'/'4. Backtesting'/from_anthony/trade_record

# %%
pwd

# %%
code = "IBM"
file_name = f"TWAP_{code}"
action_twap.to_csv(f"{file_name}.csv")

# %%
#from datetime import datetime
#def standard_date_format(date_in_num):
#    date = str(date_in_num)
#    return datetime.strptime(date,'%Y%m%d').strftime('%Y-%m-%d')

# %% [markdown]
# # Load Model

# %%
with open(model_folder+"TWAP.pickle", "rb") as f:
    twap_test = pickle.load(f)

# %% [markdown]
# # Backtesting for TWAP

# %%
import os

file_list = list(filter(lambda file: "TWAP" in file,os.listdir(record_folder)))
print(file_list)
if len(file_list) == 0:
  for file in file_list:
    #os.remove(record_folder+file)
    #print("Removing file:",file)
    pass
# Out:
# ['TWAP_Entertainment-DIS_20200101-to-20201231(-23.58%).csv', 'TWAP_Entertainment-DIS_20210101-to-20211231(12.3%).csv', 'TWAP_Entertainment-NFLX_20200101-to-20201231(-53.17%).csv', 'TWAP_Entertainment-NFLX_20210101-to-20211231(-19.36%).csv', 'TWAP_Entertainment-FB_20200101-to-20201231(-24.46%).csv', 'TWAP_Entertainment-FB_20210101-to-20211231(-31.31%).csv', 'TWAP_Entertainment-DIS_20200101-to-20201231(-37.64%).csv', 'TWAP_Entertainment-DIS_20210101-to-20211231(0.78%).csv', 'TWAP_Entertainment-NFLX_20200101-to-20201231(-77.62%).csv', 'TWAP_Entertainment-NFLX_20210101-to-20211231(-32.24%).csv', 'TWAP_Entertainment-FB_20200101-to-20201231(-16.33%).csv', 'TWAP_Entertainment-FB_20210101-to-20211231(-13.97%).csv', 'TWAP_BlockChain-COIN_20210101-to-20211231(-1.03%).csv', 'TWAP_BlockChain-NVDA_20120101-to-20121231(-0.11%).csv', 'TWAP_BlockChain-NVDA_20130101-to-20131231(-4.58%).csv', 'TWAP_BlockChain-NVDA_20140101-to-20141231(-10.0%).csv', 'TWAP_BlockChain-NVDA_20150101-to-20151231(-55.28%).csv', 'TWAP_BlockChain-NVDA_20160101-to-20161231(-213.64%).csv', 'TWAP_BlockChain-NVDA_20170101-to-20171231(-80.47%).csv', 'TWAP_BlockChain-NVDA_20180101-to-20181231(31.73%).csv', 'TWAP_BlockChain-NVDA_20190101-to-20191231(-59.13%).csv', 'TWAP_BlockChain-NVDA_20200101-to-20201231(-122.47%).csv', 'TWAP_BlockChain-NVDA_20210101-to-20211231(-51.22%).csv', 'TWAP_BlockChain-FB_20120101-to-20121231(1.2%).csv', 'TWAP_BlockChain-FB_20130101-to-20131231(-42.39%).csv', 'TWAP_BlockChain-FB_20140101-to-20141231(-48.95%).csv', 'TWAP_BlockChain-FB_20150101-to-20151231(-43.17%).csv', 'TWAP_BlockChain-FB_20160101-to-20161231(-9.79%).csv', 'TWAP_BlockChain-FB_20170101-to-20171231(-30.99%).csv', 'TWAP_BlockChain-FB_20180101-to-20181231(11.39%).csv', 'TWAP_BlockChain-FB_20190101-to-20191231(-36.79%).csv', 'TWAP_BlockChain-FB_20200101-to-20201231(-16.33%).csv', 'TWAP_BlockChain-FB_20210101-to-20211231(-13.97%).csv', 'TWAP_Airline-BA_20120101-to-20121231(-5.47%).csv', 'TWAP_Airline-BA_20130101-to-20131231(-78.33%).csv', 'TWAP_Airline-BA_20140101-to-20141231(8.27%).csv', 'TWAP_Airline-BA_20150101-to-20151231(-7.98%).csv', 'TWAP_Airline-BA_20160101-to-20161231(-25.59%).csv', 'TWAP_Airline-BA_20170101-to-20171231(-52.83%).csv', 'TWAP_Airline-BA_20180101-to-20181231(-15.67%).csv', 'TWAP_Airline-BA_20190101-to-20191231(12.94%).csv', 'TWAP_Airline-BA_20200101-to-20201231(12.5%).csv', 'TWAP_Airline-BA_20210101-to-20211231(-6.42%).csv', 'TWAP_Airline-GD_20120101-to-20121231(-10.32%).csv', 'TWAP_Airline-GD_20130101-to-20131231(-21.4%).csv', 'TWAP_Airline-GD_20140101-to-20141231(-14.8%).csv', 'TWAP_Airline-GD_20150101-to-20151231(-9.99%).csv', 'TWAP_Airline-GD_20160101-to-20161231(-16.25%).csv', 'TWAP_Airline-GD_20170101-to-20171231(-24.48%).csv', 'TWAP_Airline-GD_20180101-to-20181231(11.8%).csv', 'TWAP_Airline-GD_20190101-to-20191231(-14.1%).csv', 'TWAP_Airline-GD_20200101-to-20201231(-5.98%).csv', 'TWAP_Airline-GD_20210101-to-20211231(-34.98%).csv', 'TWAP_Airline-LMT_20120101-to-20121231(-21.14%).csv', 'TWAP_Airline-LMT_20130101-to-20131231(-38.73%).csv', 'TWAP_Airline-LMT_20140101-to-20141231(-11.71%).csv', 'TWAP_Airline-LMT_20150101-to-20151231(-11.07%).csv', 'TWAP_Airline-LMT_20160101-to-20161231(-9.32%).csv', 'TWAP_Airline-LMT_20170101-to-20171231(-31.58%).csv', 'TWAP_Airline-LMT_20180101-to-20181231(8.1%).csv', 'TWAP_Airline-LMT_20190101-to-20191231(-35.3%).csv', 'TWAP_Airline-LMT_20200101-to-20201231(10.7%).csv', 'TWAP_Airline-LMT_20210101-to-20211231(-3.38%).csv', 'TWAP_Traveling-UBER_20190101-to-20191231(10.17%).csv', 'TWAP_Traveling-UBER_20200101-to-20201231(51.24%).csv', 'TWAP_Traveling-UBER_20210101-to-20211231(21.66%).csv', 'TWAP_Traveling-ABNB_20200101-to-20201231(2.64%).csv', 'TWAP_Traveling-ABNB_20210101-to-20211231(-5.42%).csv', 'TWAP_Traveling-MAR_20120101-to-20121231(-12.83%).csv', 'TWAP_Traveling-MAR_20130101-to-20131231(-20.62%).csv', 'TWAP_Traveling-MAR_20140101-to-20141231(-32.28%).csv', 'TWAP_Traveling-MAR_20150101-to-20151231(4.15%).csv', 'TWAP_Traveling ...

# %%
#### TWAP Backtest
backtest_summary = pd.DataFrame(columns=backtest_col)

for sector, stocks in stock_list.items():
    for stock in stocks:
        print("Runninng stock: "+ stock)
        stock_data_1 = web.DataReader(stock, "stooq",start=start_date, end=end_date)
        stock_data_1.columns = ["open","high","low","close","volume"]
        x_1 = StockDataFrame(stock_data_1)
        print("entire dataset",len(x_1))
        data_1 = x_1[['open','high','low','close','volume',
                      'boll', 'boll_ub', 'boll_lb',
                      'macd', 'macdh', 'macds',
                      'rsi_11', 'rsi_14', 'rsi_21']]
        data_1.index = [int(str(ind)[0:4]+str(ind)[5:7]+str(ind)[8:10]) for ind in data_1.index]
        data_1 = data_1.sort_index()

        print("data_1 length",len(data_1))
        
        print(stock + " Data loaded...")
        
        for k,v in date_range_list.items():
         
            print("Getting Data... - " + stock + " from " + str(k))
            if (data_1.index[0]>v):
                print("No data for this testing period... - " + stock + " from " + str(k))
                continue
            test_X = custom_split(data_1,start = k,end = v)
            if len(test_X) <= num_day_to_predict:
                print("No enough data for testing... - " + stock + " from " + str(k))
                continue
                
            print("Transforming Data... - " + stock + " from " + str(k))
            test_y = produce_result_target_price(test_X,num_day_to_predict)
            test_X_5 = transform_x_data_to_one_vector(test_X,num_day_to_predict)
            new_test_X_5  = drop_nan_row_X_5(test_X_5,num_day_to_predict)
            new_test_y = drop_nan_row_y(test_y,num_day_to_predict)
            old_test_X_5 = new_test_X_5.copy()
            old_test_y = new_test_y.copy()
            new_test_X_5,new_test_y = normalize_data_by_row(new_test_X_5,new_test_y)

            final_train = twap(new_train_X_5)
            final_valid = twap(new_valid_X_5)
            final_test = twap(new_test_X_5)
            final_pred = twap(new_pred_X_5)

            for i in range(5):
              #df_ = final.filter(like=f"-{i}")
              final_train[f"TWAP_{i}"] = (final_train[f"open-{i}"]+final_train[f"close-{i}"]+final_train[f"high-{i}"]+final_train[f"low-{i}"])/4
              final_test[f"TWAP_{i}"] = (final_test[f"open-{i}"]+final_test[f"close-{i}"]+final_test[f"high-{i}"]+final_test[f"low-{i}"])/4
              final_valid[f"TWAP_{i}"] = (final_valid[f"open-{i}"]+final_valid[f"close-{i}"]+final_valid[f"high-{i}"]+final_valid[f"low-{i}"])/4
              final_pred[f"TWAP_{i}"] = (final_pred[f"open-{i}"]+final_pred[f"close-{i}"]+final_pred[f"high-{i}"]+final_pred[f"low-{i}"])/4


            new_train_X_5 = final_train
            new_test_X_5 = final_test 
            new_valid_X_5 = final_valid
            new_pred_X_5 = final_pred


            #print("lengths of train,test,valid,pred",len(new_train_X_5),len(new_test_X_5),len(new_valid_X_5),len(new_pred_X_5))
            #print("length of data_1 ", len(data_1))

            print("Predicting... - " + stock + " from " + str(k))
            twap_pred = twap_test.predict(new_test_X_5)
            #print("input length",len(new_test_X_5))
            #print("prediction length",len(twap_pred))
            
            print("Converting... - " + stock + " from " + str(k))
            pred_price = convert_prediction(old_test_X_5,old_test_y,twap_pred.flatten())

            data_copy = data_1

            pred_action = convert_decision(data_copy,pred_price)
            #pred_df["Action"] = pred_df.apply(lambda row: "Buy" if row["converted"] > row["mean"] else "Sell", axis=1)
            #final_pred = pred_df.drop(columns=["mean","std","pred","converted"])
            final_test_y = old_test_y.rename(columns={"result_price":"Open"})
            #final_pred = final_pred.sort_index()
            
            print("Backtesting... - " + stock + " from " + str(k))
            back1 = backtest(final_test_y,pred_action,10000,0.0005,period_year)
            back1.clear_trade_record(3)
            
            print("Start Iteration... - " + stock + " from " + str(k))
            back1.start_test()
            
            print("======= from "+ str(k) + " to " + str(v)+" =========")
            back1.print_do_nothing()
            back1.print_profit()
            back1.print_CAGR_performance()
            back1.export_trade_record("TWAP_"+sector+"-"+stock,str(k)+"-to-"+str(v)+"("+str(round(back1.get_diff_in_CAGR()*100,2))+"%)")
            backtest_summary = backtest_summary.append({"Sector":sector,
                                                        "Stock":stock,
                                                        "Range_Start":str(k),
                                                        "Range_End":str(v),
                                                        do_nth_name+"_Profit":round(back1.get_do_nothing(),2),
                                                        model_name+"_Profit":round(back1.get_profit(),2),
                                                        do_nth_name+"_CAGR(in %)":round(back1.get_do_nothing_CAGR()*100,2),
                                                        model_name+"_CAGR(in %)":round(back1.get_model_CAGR()*100,2),
                                                        "CAGR_Performance(in %)":round(back1.get_diff_in_CAGR()*100,2),
                                                        do_nth_name+"_MDD(in %)":round(back1.get_do_nothing_MDD()*100,2),
                                                        model_name+"_MDD(in %)":round(back1.get_model_MDD()*100,2),
                                                        "MDD_Performance(in %)":round(back1.get_diff_in_MDD()*100,2)}, ignore_index=True)
            print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
            time.sleep(3)

print("Backtesting Completed...")
backtest_summary.to_csv(backtest_summary_folder+"backtest_summary_twap.csv")
# Out:
# Runninng stock: COIN
# entire dataset 256
# data_1 length 256
# COIN Data loaded...
# Getting Data... - COIN from 20120101
# No data for this testing period... - COIN from 20120101
# Getting Data... - COIN from 20130101
# No data for this testing period... - COIN from 20130101
# Getting Data... - COIN from 20140101
# No data for this testing period... - COIN from 20140101
# Getting Data... - COIN from 20150101
# No data for this testing period... - COIN from 20150101
# Getting Data... - COIN from 20160101
# No data for this testing period... - COIN from 20160101
# Getting Data... - COIN from 20170101
# No data for this testing period... - COIN from 20170101
# Getting Data... - COIN from 20180101
# No data for this testing period... - COIN from 20180101
# Getting Data... - COIN from 20190101
# No data for this testing period... - COIN from 20190101
# Getting Data... - COIN from 20200101
# No data for this testing period... - COIN from 20200101
# Getting Data... - COIN from 20210101
# Transforming Data... - COIN from 20210101
# Predicting... - COIN from 20210101
# Converting... - COIN from 20210101
# Backtesting... - COIN from 20210101
# Clearing trade_record...
# Start Iteration... - COIN from 20210101
# Start Backtesting...
# Bought at 20210510 with price = 281.05 	Pos: 35
# Sold at 20210514 with price = 250.0 	Pos: 35
# Bought at 20210525 with price = 247.5 	Pos: 35
# Sold at 20210601 with price = 242.7962 	Pos: 35
# Bought at 20210614 with price = 236.227 	Pos: 36
# Sold at 20210616 with price = 226.88 	Pos: 36
# Bought at 20210617 with price = 226.92 	Pos: 36
# Sold at 20210618 with price = 223.14 	Pos: 36
# Bought at 20210623 with price = 228.46 	Pos: 36
# Sold at 20210702 with price = 243.0 	Pos: 36
# Bought at 20210707 with price = 239.0 	Pos: 36
# Sold at 20210714 with price = 229.94 	Pos: 36
# Bought at 20210721 with price = 232.0 	Pos: 36
# Sold at 20210729 with price = 233.28 	Pos: 36
# Bought at 20210804 with price = 239.76 	Pos: 35
# Sold at 20210812 with price = 262.82 	Pos: 35
# Bought at 20210820 with price = 263.6663 	Pos: 35
# Sold at 20210826 with price = 249.39 	Pos: 35
# Bought at 20210827 with price = 256.3482 	Pos: 34
# Sold at 20210908 with price = 260.3 	Pos: 34
# Bought at 20210917 with price = 234.45 	Pos: 37
# Sold at 20210920 with price = 237.01 	Pos: 37
# Bought at 20210922 with price = 244.57 	Pos: 36
# Sold at 20210923 with price = 231.0 	Pos: 36
# Bought at 20211001 with price = 231.49 	Pos: 36
# Sold at 20211004 with price = 231.35 	Pos: 36
# Bought at 20211005 with price = 242.4 	Pos: 34
# Sold at 20211013 with price = 250.9 	Pos: 34
# Bought at 20211014 with price = 266.6 	Pos: 32
# Sold at 20211105 with price = 349.5009 	Pos: 32
# Bought at 20211108 with price = 367.39 	Pos: 30
# Sold at 20211110 with price = 327.428 	Pos: 30
# Bought at 20211112 with price = 345.1 	Pos: 29
# Sold at 20211118 with price = 325.56 	Pos: 29
# Bought at 20211129 with price = 320.75 	Pos: 29
# Sold at 20211201 with price = 295.16 	Pos: 29
# Bought at 20211208 with price = 284.97 	Pos: 30
# Sold at 20211209 with price = 266.3 	Pos: 30
# Bought at 20211222 with price = 256.555 	Pos: 32
# Sold at 20211229 with price = 252.6 	Pos: 32
# ======= from 20210101 to 20211231 =========
# If buy at 20210420 with price = 312.52
# and do nothing
# Current Profit: -1762.8540599999978
# Current Profit with model: -1865.6251285499839
# CAGR Performance: -1.03%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Runninng stock: NVDA
# entire dataset 5609
# data_1 length 5609
# NVDA Data loaded...
# Getting Data... - NVDA from 20120101
# Transforming Data... - NVDA from 20120101
# Predicting... - NVDA from 20120101
# Converting... - NVDA from 20120101
# Backtesting... - NVDA from 20120101
# Clearing trade_record...
# Start Iteration... - NVDA from 20120101
# Start Backtesting...
# Bought at 20120109 with price = 3.3894 	Pos: 2948
# Sold at 20120111 with price = 3.265 	Pos: 2948
# Bought at 20120119 with price = 3.2896 	Pos: 2923
# Sold at 20120210 with price = 3.7433 	Pos: 2923
# Bought at 20120216 with price = 3.7731 	Pos: 2897
# Sold at 20120217 with price = 3.6376 	Pos: 2897
# Bought at 20120323 with price = 3.3694 	Pos: 3125
# Sold at 20120403 with price = 3.4088 	Pos: 3125
# Bought at 20120412 with price = 3.3416 	Pos: 3185
# Sold at 20120413 with price = 3.2718 	Pos: 3185
# Bought at 20120501 with price = 3.0264 	Pos: 3439
# Sold at 20120502 with price = 2.9574 	Pos: 3439
# Bought at 20120509 with price = 2.9004 	Pos: 3504
# Sold at 20120516 with price = 2.9369 	Pos: 3504
# Bought at 20120523 with price = 2.8709 	Pos: 3581
# Sold at 20120524 with price = 2.7783 	Pos: 3581
# Bought at 20120525 with price = 2.8934 	Pos: 3435
# Sold at 20120601 with price = 2.7643 	Pos: 3435
# Bought at 20120606 with price = 2.8864 	Pos: 3286
# Sold at 20120607 with price = 2.7388 	Pos: 3286
# Bought at 20120608 with price = 2.8727 	Pos: 3130
# Sold at 20120613 with price = 2.7926 	Pos: 3130
# Bought at 20120618 with price = 2.9647 	Pos: 2945
# Sold at 20120625 with price = 2.9077 	Pos: 2945
# Bought at 20120627 with price = 2.9899 	Pos: 2861
# Sold at 20120706 with price = 3.0577 	Pos: 2861
# Bought at 20120718 with price = 3.0192 	Pos: 2895
# Sold at 20120815 with price = 3.3551 	Pos: 2895
# Bought at 20120824 with price = 3.3508 	Pos: 2896
# Sold at 20120827 with price = 3.2695 	Pos: 2896
# Bought at 20120911 with price = 3.1114 	Pos: 3040
# Sold at 20120917 with price = 3.0559 	Pos: 3040
# Bought at 20120919 with price = 3.1413 	Pos: 2954
# Sold at 20120920 with price = 3.1298 	Pos: 2954
# Bought at 20120921 with price = 3.0881 	Pos: 2991
# Sold at 20120925 with price = 3.0671 	Pos: 2991
# Bought at 20121004 with price = 3.1363 	Pos: 2922
# Sold at 20121008 with price = 3.0192 	Pos: 2922
# Bought at 20121015 with price = 2.9621 	Pos: 2975
# Sold at 20121019 with price = 2.7926 	Pos: 2975
# Bought at 20121101 with price = 2.9124 	Pos: 2850
# Sold at 20121109 with price = 2.8039 	Pos: 2850
# Bought at 20121119 with price = 2.6756 	Pos: 2984
# Sold at 20121120 with price = 2.6556 	Pos: 2984
# Bought at 20121121 with price = 2.7426 	Pos: 2886
# Sold at 20121130 with price = 2.7851 	Pos: 2886
# Bought at 20121204 with price = 2.7734 	Pos: 2896
# Sold at 20121205 with price = 2.7571 	Pos: 2896
# Bought at 20121206 with price = 2.7709 	Pos: 2878
# Sold at 20121221 with price = 2.8528 	Pos: 2878
# ======= from 20120101 to 20121231 =========
# If buy at 20120109 with price = 3.3894
# and do nothing
# Current Profit: -1779.9867756000003
# Current Profit with model: -1791.143254849976
# CAGR Performance: -0.11%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - NVDA from 20130101
# Transforming Data... - NVDA from 20130101
# Predicting... - NVDA from 20130101
# Converting... - NVDA from 20130101
# Backtesting... - NVDA from 20130101
# Clearing trade_record...
# Start Iteration... - NVDA from 20130101
# Start Backtesting...
# Bought at 20130117 with price = 2.8316 	Pos: 3529
# Sold at 20130118 with price = 2.8109 	Pos: 3529
# Bought at 20130124 with price = 2.8219 	Pos: 3512
# Sold at 20130131 with price = 2.8458 	Pos: 3512
# Bought at 20130205 with price = 2.8059 	Pos: 3558
# Sold at 20130207 with price = 2.8596 	Pos: 3558
# Bought at 20130208 with price = 2.8822 	Pos: 3527
# Sold at 20130213 with price = 2.8199 	Pos: 3527
# Bought at 20130214 with price = 2.9354 	Pos: 3385
# Sold at 20130220 with price = 2.8572 	Pos: 3385
# Bought at 20130227 with price = 2.9211 	Pos: 3307
# Sold at 20130311 with price = 2.9484 	Pos: 3307
# Bought at 20130327 with price = 2.9347 	Pos: 3320
# Sold at 20130401 with price = 2.8881 	Pos: 3320
# Bought at 20130405 with price = 2.8997 	Pos: 3303
# Sold at 20130417 with price = 2.9924 	Pos: 3303
# Bought at 20130423 with price = 3.0107 	Pos: 3280
# Sold at 20130507 with price = 3.1783 	Pos: 3280
# Bought at 20130508 with price = 3.1736 	Pos: 3281
# Sold at 20130522 with price = 3.3261 	Pos: 3281
# Bought at 20130530 with price = 3.4008 	Pos: 3206
# Sold at 20130531 with price = 3.3868 	Pos: 3206
# Bought at 20130613 with price = 3.3708 	Pos: 3218
# Sold at 20130621 with price = 3.3214 	Pos: 3218
# Bought at 20130703 with price = 3.3118 	Pos: 3224
# Sold at 20130708 with price = 3.3188 	Pos: 3224
# Bought at 20130709 with price = 3.3284 	Pos: 3211
# Sold at 20130717 with price = 3.4088 	Pos: 3211
# Bought at 20130730 with price = 3.3516 	Pos: 3263
# Sold at 20130807 with price = 3.4304 	Pos: 3263
# Bought at 20130813 with price = 3.3636 	Pos: 3324
# Sold at 20130821 with price = 3.4928 	Pos: 3324
# Bought at 20130904 with price = 3.4861 	Pos: 3327
# Sold at 20130906 with price = 3.5236 	Pos: 3327
# Bought at 20130909 with price = 3.5796 	Pos: 3272
# Sold at 20130917 with price = 3.7283 	Pos: 3272
# Bought at 20130918 with price = 3.7751 	Pos: 3228
# Sold at 20130919 with price = 3.7515 	Pos: 3228
# Bought at 20131014 with price = 3.6386 	Pos: 3325
# Sold at 20131015 with price = 3.6408 	Pos: 3325
# Bought at 20131016 with price = 3.6361 	Pos: 3326
# Sold at 20131022 with price = 3.6976 	Pos: 3326
# Bought at 20131108 with price = 3.6408 	Pos: 3375
# Sold at 20131118 with price = 3.6892 	Pos: 3375
# Bought at 20131125 with price = 3.7034 	Pos: 3358
# Sold at 20131129 with price = 3.6696 	Pos: 3358
# Bought at 20131202 with price = 3.7198 	Pos: 3310
# Sold at 20131203 with price = 3.7078 	Pos: 3310
# Bought at 20131204 with price = 3.7765 	Pos: 3246
# Sold at 20131205 with price = 3.7528 	Pos: 3246
# Bought at 20131218 with price = 3.6128 	Pos: 3369
# Sold at 20131226 with price = 3.7198 	Pos: 3369
# Bought at 20131230 with price = 3.7788 	Pos: 3313
# ======= from 20130101 to 20131231 =========
# If buy at 20130108 with price = 2.9101
# and do nothing
# Current Profit: 2978.1191583
# Current Profit with model: 2520.178283600042
# CAGR Performance: -4.58%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - NVDA from 20140101
# Transforming Data... - NVDA from 20140101
# Predicting... - NVDA from 20140101
# Converting... - NVDA from 20140101
# Backtesting... - NVDA from 20140101
# Clearing trade_record...
# Start Iteration... - NVDA from 20140101
# Start Backtesting...
# Bought at 20140108 with price = 3.8048 	Pos: 2626
# Sold at 20140109 with price = 3.7318 	Pos: 2626
# Bought at 20140115 with price = 3.7813 	Pos: 2589
# Sold at 20140122 with price = 3.7741 	Pos: 2589
# Bought at 20140130 with price = 3.6606 	Pos: 2667
# Sold at 20140203 with price = 3.6556 	Pos: 2667
# Bought at 20140206 with price = 3.7034 	Pos: 2630
# Sold at 20140227 with price = 4.3648 	Pos: 2630
# Bought at 20140305 with price = 4.4287 	Pos: 2589
# Sold at 20140306 with price = 4.3792 	Pos: 2589
# Bought at 20140318 with price = 4.3598 	Pos: 2598
# Sold at 20140325 with price = 4.4166 	Pos: 2598
# Bought at 20140401 with price = 4.4237 	Pos: 2592
# Sold at 20140404 with price = 4.3082 	Pos: 2592
# Bought at 20140408 with price = 4.5003 	Pos: 2478
# Sold at 20140410 with price = 4.3225 	Pos: 2478
# Bought at 20140417 with price = 4.4049 	Pos: 2430
# Sold at 20140425 with price = 4.4602 	Pos: 2430
# Bought at 20140512 with price = 4.348 	Pos: 2490
# Sold at 20140514 with price = 4.2842 	Pos: 2490
# Bought at 20140519 with price = 4.3998 	Pos: 2422
# Sold at 20140602 with price = 4.5236 	Pos: 2422
# Bought at 20140606 with price = 4.5333 	Pos: 2414
# Sold at 20140618 with price = 4.5882 	Pos: 2414
# Bought at 20140701 with price = 4.4522 	Pos: 2486
# Sold at 20140708 with price = 4.4591 	Pos: 2486
# Bought at 20140709 with price = 4.4687 	Pos: 2478
# Sold at 20140718 with price = 4.378 	Pos: 2478
# Bought at 20140730 with price = 4.2608 	Pos: 2544
# Sold at 20140731 with price = 4.1706 	Pos: 2544
# Bought at 20140808 with price = 4.5333 	Pos: 2338
# Sold at 20140814 with price = 4.4948 	Pos: 2338
# Bought at 20140818 with price = 4.601 	Pos: 2281
# Sold at 20140821 with price = 4.5608 	Pos: 2281
# Bought at 20140826 with price = 4.6267 	Pos: 2247
# Sold at 20140909 with price = 4.7032 	Pos: 2247
# Bought at 20140918 with price = 4.6675 	Pos: 2262
# Sold at 20140919 with price = 4.6602 	Pos: 2262
# Bought at 20141016 with price = 4.2266 	Pos: 2491
# Sold at 20141107 with price = 4.7369 	Pos: 2491
# Bought at 20141118 with price = 4.819 	Pos: 2446
# Sold at 20141201 with price = 4.9491 	Pos: 2446
# Bought at 20141203 with price = 5.0746 	Pos: 2383
# Sold at 20141204 with price = 5.0382 	Pos: 2383
# Bought at 20141205 with price = 5.0549 	Pos: 2373
# Sold at 20141208 with price = 4.9691 	Pos: 2373
# Bought at 20141217 with price = 4.9014 	Pos: 2403
# Sold at 20141224 with price = 4.9446 	Pos: 2403
# ======= from 20140101 to 20141231 =========
# If buy at 20140108 with price = 3.8048
# and do nothing
# Current Profit: 2880.9782976000006
# Current Profit with model: 1880.4877351500309
# CAGR Performance: -10.0%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - NVDA from 20150101
# Transforming Data... - NVDA from 20150101
# Predicting... - NVDA from 20150101
# Converting... - NVDA from 20150101
# Backtesting... - NVDA from 20150101
# Clearing trade_record...
# Start Iteration... - NVDA from 20150101
# Start Backtesting...
# Bought at 20150109 with price = 4.8049 	Pos: 2080
# Sold at 20150113 with price = 4.6822 	Pos: 2080
# Bought at 20150116 with price = 4.8238 	Pos: 2017
# Sold at 20150127 with price = 4.7765 	Pos: 2017
# Bought at 20150203 with price = 4.819 	Pos: 1997
# Sold at 20150219 with price = 5.3273 	Pos: 1997
# Bought at 20150302 with price = 5.4107 	Pos: 1964
# Sold at 20150303 with price = 5.3335 	Pos: 1964
# Bought at 20150304 with price = 5.413 	Pos: 1933
# Sold at 20150312 with price = 5.4435 	Pos: 1933
# Bought at 20150316 with price = 5.5256 	Pos: 1903
# Sold at 20150318 with price = 5.5381 	Pos: 1903
# Bought at 20150319 with price = 5.649 	Pos: 1863
# Sold at 20150323 with price = 5.4629 	Pos: 1863
# Bought at 20150406 with price = 5.2289 	Pos: 1945
# Sold at 20150414 with price = 5.4107 	Pos: 1945
# Bought at 20150415 with price = 5.429 	Pos: 1936
# Sold at 20150416 with price = 5.3235 	Pos: 1936
# Bought at 20150428 with price = 5.3453 	Pos: 1927
# Sold at 20150430 with price = 5.4007 	Pos: 1927
# Bought at 20150501 with price = 5.4779 	Pos: 1898
# Sold at 20150505 with price = 5.3695 	Pos: 1898
# Bought at 20150514 with price = 5.1599 	Pos: 1973
# Sold at 20150519 with price = 5.1032 	Pos: 1973
# Bought at 20150527 with price = 5.2944 	Pos: 1899
# Sold at 20150603 with price = 5.2286 	Pos: 1899
# Bought at 20150605 with price = 5.3821 	Pos: 1843
# Sold at 20150608 with price = 5.2776 	Pos: 1843
# Bought at 20150617 with price = 5.2751 	Pos: 1843
# Sold at 20150623 with price = 5.1376 	Pos: 1843
# Bought at 20150713 with price = 4.8261 	Pos: 1959
# Sold at 20150715 with price = 4.8162 	Pos: 1959
# Bought at 20150716 with price = 4.8774 	Pos: 1933
# Sold at 20150720 with price = 4.7657 	Pos: 1933
# Bought at 20150728 with price = 4.7732 	Pos: 1928
# Sold at 20150814 with price = 5.6962 	Pos: 1928
# Bought at 20150827 with price = 5.5088 	Pos: 1992
# Sold at 20150901 with price = 5.3922 	Pos: 1992
# Bought at 20150908 with price = 5.5381 	Pos: 1937
# Sold at 20150909 with price = 5.3803 	Pos: 1937
# Bought at 20150910 with price = 5.4354 	Pos: 1916
# Sold at 20150922 with price = 5.5765 	Pos: 1916
# Bought at 20150924 with price = 5.7765 	Pos: 1847
# Sold at 20150928 with price = 5.733 	Pos: 1847
# Bought at 20150929 with price = 5.8248 	Pos: 1816
# Sold at 20151020 with price = 6.802 	Pos: 1816
# Bought at 20151022 with price = 6.9741 	Pos: 1770
# Sold at 20151026 with price = 6.894 	Pos: 1770
# Bought at 20151106 with price = 7.6048 	Pos: 1603
# Sold at 20151112 with price = 7.4076 	Pos: 1603
# Bought at 20151201 with price = 8.0147 	Pos: 1480
# Sold at 20151202 with price = 8.0049 	Pos: 1480
# Bought at 20151204 with price = 8.2447 	Pos: 1435
# Sold at 20151207 with price = 7.9904 	Pos: 1435
# ======= from 20150101 to 20151231 =========
# If buy at 20150108 with price = 4.7912
# and do nothing
# Current Profit: 6994.7843784
# Current Profit with model: 1466.723127800029
# CAGR Performance: -55.28%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - NVDA from 20160101
# Transforming Data... - NVDA from 20160101
# Predicting... - NVDA from 20160101
# Converting... - NVDA from 20160101
# Backtesting... - NVDA from 20160101
# Clearing trade_record...
# Start Iteration... - NVDA from 20160101
# Start Backtesting...
# Bought at 20160121 with price = 6.9227 	Pos: 1443
# Sold at 20160128 with price = 6.913 	Pos: 1443
# Bought at 20160129 with price = 7.15 	Pos: 1394
# Sold at 20160202 with price = 6.9104 	Pos: 1394
# Bought at 20160212 with price = 6.3773 	Pos: 1509
# Sold at 20160229 with price = 7.7108 	Pos: 1509
# Bought at 20160301 with price = 7.9876 	Pos: 1455
# Sold at 20160307 with price = 7.8503 	Pos: 1455
# Bought at 20160314 with price = 7.88 	Pos: 1448
# Sold at 20160405 with price = 8.6569 	Pos: 1448
# Bought at 20160411 with price = 8.829 	Pos: 1419
# Sold at 20160419 with price = 8.89 	Pos: 1419
# Bought at 20160427 with price = 9.0932 	Pos: 1386
# Sold at 20160428 with price = 8.8413 	Pos: 1386
# Bought at 20160510 with price = 8.846 	Pos: 1383
# Sold at 20160512 with price = 9.611 	Pos: 1383
# Bought at 20160513 with price = 9.974 	Pos: 1332
# Sold at 20160603 with price = 11.458 	Pos: 1332
# Bought at 20160609 with price = 11.512 	Pos: 1324
# Sold at 20160610 with price = 11.372 	Pos: 1324
# Bought at 20160615 with price = 11.559 	Pos: 1301
# Sold at 20160616 with price = 11.706 	Pos: 1301
# Bought at 20160623 with price = 11.434 	Pos: 1331
# Sold at 20160624 with price = 11.151 	Pos: 1331
# Bought at 20160630 with price = 11.494 	Pos: 1290
# Sold at 20160715 with price = 13.118 	Pos: 1290
# Bought at 20160720 with price = 13.303 	Pos: 1271
# Sold at 20160721 with price = 13.133 	Pos: 1271
# Bought at 20160722 with price = 13.524 	Pos: 1233
# Sold at 20160727 with price = 13.817 	Pos: 1233
# Bought at 20160808 with price = 14.514 	Pos: 1172
# Sold at 20160810 with price = 14.463 	Pos: 1172
# Bought at 20160812 with price = 15.517 	Pos: 1092
# Sold at 20160817 with price = 15.013 	Pos: 1092
# Bought at 20160915 with price = 15.496 	Pos: 1056
# Sold at 20160920 with price = 15.587 	Pos: 1056
# Bought at 20160921 with price = 16.07 	Pos: 1024
# Sold at 20160922 with price = 16.036 	Pos: 1024
# Bought at 20160927 with price = 16.416 	Pos: 999
# Sold at 20160928 with price = 16.423 	Pos: 999
# Bought at 20160929 with price = 16.694 	Pos: 982
# Sold at 20161003 with price = 16.887 	Pos: 982
# Bought at 20161024 with price = 17.389 	Pos: 952
# Sold at 20161027 with price = 17.495 	Pos: 952
# Bought at 20161111 with price = 21.699 	Pos: 767
# Sold at 20161121 with price = 22.984 	Pos: 767
# Bought at 20161215 with price = 24.629 	Pos: 715
# Sold at 20161221 with price = 26.354 	Pos: 715
# Bought at 20161227 with price = 29.507 	Pos: 638
# Sold at 20161228 with price = 25.882 	Pos: 638
# ======= from 20160101 to 20161231 =========
# If buy at 20160108 with price = 7.2477
# and do nothing
# Current Profit: 27880.175410850003
# Current Profit with model: 6515.8889878500595
# CAGR Performance: -213.64%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - NVDA from 20170101
# Transforming Data... - NVDA from 20170101
# Predicting... - NVDA from 20170101
# Converting... - NVDA from 20170101
# Backtesting... - NVDA from 20170101
# Clearing trade_record...
# Start Iteration... - NVDA from 20170101
# Start Backtesting...
# Bought at 20170109 with price = 26.596 	Pos: 375
# Sold at 20170111 with price = 25.714 	Pos: 375
# Bought at 20170119 with price = 26.17 	Pos: 368
# Sold at 20170120 with price = 25.607 	Pos: 368
# Bought at 20170123 with price = 26.03 	Pos: 362
# Sold at 20170131 with price = 27.276 	Pos: 362
# Bought at 20170201 with price = 27.953 	Pos: 353
# Sold at 20170209 with price = 29.587 	Pos: 353
# Bought at 20170221 with price = 27.521 	Pos: 379
# Sold at 20170223 with price = 23.979 	Pos: 379
# Bought at 20170313 with price = 25.291 	Pos: 359
# Sold at 20170323 with price = 26.916 	Pos: 359
# Bought at 20170330 with price = 26.926 	Pos: 359
# Sold at 20170403 with price = 25.54 	Pos: 359
# Bought at 20170417 with price = 24.368 	Pos: 375
# Sold at 20170428 with price = 25.874 	Pos: 375
# Bought at 20170501 with price = 26.07 	Pos: 372
# Sold at 20170502 with price = 25.491 	Pos: 372
# Bought at 20170510 with price = 29.651 	Pos: 320
# Sold at 20170517 with price = 31.988 	Pos: 320
# Bought at 20170518 with price = 33.884 	Pos: 301
# Sold at 20170525 with price = 34.101 	Pos: 301
# Bought at 20170526 with price = 35.534 	Pos: 289
# Sold at 20170602 with price = 35.358 	Pos: 289
# Bought at 20170605 with price = 36.554 	Pos: 279
# Sold at 20170609 with price = 36.071 	Pos: 279
# Bought at 20170616 with price = 37.938 	Pos: 265
# Sold at 20170623 with price = 38.364 	Pos: 265
# Bought at 20170707 with price = 37.032 	Pos: 274
# Sold at 20170724 with price = 40.857 	Pos: 274
# Bought at 20170803 with price = 41.394 	Pos: 270
# Sold at 20170810 with price = 38.854 	Pos: 270
# Bought at 20170815 with price = 41.441 	Pos: 253
# Sold at 20170816 with price = 40.757 	Pos: 253
# Bought at 20170823 with price = 41.357 	Pos: 249
# Sold at 20170825 with price = 40.734 	Pos: 249
# Bought at 20170831 with price = 42.063 	Pos: 241
# Sold at 20170905 with price = 41.392 	Pos: 241
# Bought at 20170911 with price = 42.076 	Pos: 237
# Sold at 20170921 with price = 44.627 	Pos: 237
# Bought at 20170929 with price = 44.747 	Pos: 236
# Sold at 20171002 with price = 44.367 	Pos: 236
# Bought at 20171004 with price = 45.01 	Pos: 233
# Sold at 20171005 with price = 44.467 	Pos: 233
# Bought at 20171009 with price = 47.375 	Pos: 218
# Sold at 20171018 with price = 48.122 	Pos: 218
# Bought at 20171027 with price = 49.957 	Pos: 210
# Sold at 20171102 with price = 51.284 	Pos: 210
# Bought at 20171110 with price = 53.495 	Pos: 201
# Sold at 20171113 with price = 52.716 	Pos: 201
# Bought at 20171211 with price = 47.772 	Pos: 222
# Sold at 20171212 with price = 47.672 	Pos: 222
# Bought at 20171218 with price = 48.921 	Pos: 216
# Sold at 20171221 with price = 48.145 	Pos: 216
# ======= from 20170101 to 20171231 =========
# If buy at 20170109 with price = 26.596
# and do nothing
# Current Profit: 8452.01325
# Current Profit with model: 405.49895700002344
# CAGR Performance: -80.47%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - NVDA from 20180101
# Transforming Data... - NVDA from 20180101
# Predicting... - NVDA from 20180101
# Converting... - NVDA from 20180101
# Backtesting... - NVDA from 20180101
# Clearing trade_record...
# Start Iteration... - NVDA from 20180101
# Start Backtesting...
# Bought at 20180108 with price = 55.033 	Pos: 181
# Sold at 20180116 with price = 54.656 	Pos: 181
# Bought at 20180117 with price = 55.463 	Pos: 178
# Sold at 20180202 with price = 56.22 	Pos: 178
# Bought at 20180209 with price = 58.29 	Pos: 172
# Sold at 20180222 with price = 60.613 	Pos: 172
# Bought at 20180306 with price = 58.984 	Pos: 176
# Sold at 20180319 with price = 59.756 	Pos: 176
# Bought at 20180320 with price = 61.786 	Pos: 170
# Sold at 20180322 with price = 60.073 	Pos: 170
# Bought at 20180404 with price = 56.65 	Pos: 181
# Sold at 20180405 with price = 53.838 	Pos: 181
# Bought at 20180410 with price = 56.33 	Pos: 172
# Sold at 20180419 with price = 56.672 	Pos: 172
# Bought at 20180426 with price = 56.87 	Pos: 172
# Sold at 20180515 with price = 60.473 	Pos: 172
# Bought at 20180523 with price = 61.349 	Pos: 169
# Sold at 20180608 with price = 64.91 	Pos: 169
# Bought at 20180614 with price = 65.616 	Pos: 167
# Sold at 20180618 with price = 64.698 	Pos: 167
# Bought at 20180702 with price = 60.42 	Pos: 179
# Sold at 20180703 with price = 59.281 	Pos: 179
# Bought at 20180705 with price = 59.948 	Pos: 176
# Sold at 20180713 with price = 61.547 	Pos: 176
# Bought at 20180717 with price = 62.834 	Pos: 173
# Sold at 20180723 with price = 62.328 	Pos: 173
# Bought at 20180725 with price = 62.256 	Pos: 173
# Sold at 20180730 with price = 60.438 	Pos: 173
# Bought at 20180802 with price = 62.394 	Pos: 167
# Sold at 20180810 with price = 63.267 	Pos: 167
# Bought at 20180814 with price = 65.035 	Pos: 162
# Sold at 20180815 with price = 64.943 	Pos: 162
# Bought at 20180822 with price = 64.783 	Pos: 163
# Sold at 20180905 with price = 68.912 	Pos: 163
# Bought at 20180914 with price = 68.337 	Pos: 164
# Sold at 20180917 with price = 68.01 	Pos: 164
# Bought at 20180928 with price = 70.506 	Pos: 158
# Sold at 20181004 with price = 69.044 	Pos: 158
# Bought at 20181017 with price = 61.003 	Pos: 178
# Sold at 20181018 with price = 59.983 	Pos: 178
# Bought at 20181030 with price = 52.016 	Pos: 206
# Sold at 20181108 with price = 50.216 	Pos: 206
# Bought at 20181115 with price = 40.52 	Pos: 255
# Sold at 20181116 with price = 40.14 	Pos: 255
# Bought at 20181126 with price = 37.713 	Pos: 271
# Sold at 20181207 with price = 36.211 	Pos: 271
# Bought at 20181212 with price = 37.451 	Pos: 262
# Sold at 20181219 with price = 34.316 	Pos: 262
# Bought at 20181226 with price = 32.532 	Pos: 276
# ======= from 20180101 to 20181231 =========
# If buy at 20180108 with price = 55.033
# and do nothing
# Current Profit: -3879.285486499999
# Current Profit with model: -706.3110694999723
# CAGR Performance: 31.73%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - NVDA from 20190101
# Transforming Data... - NVDA from 20190101
# Predicting... - NVDA from 20190101
# Converting... - NVDA from 20190101
# Backtesting... - NVDA from 20190101
# Clearing trade_record...
# Start Iteration... - NVDA from 20190101
# Start Backtesting...
# Bought at 20190108 with price = 35.246 	Pos: 283
# Sold at 20190122 with price = 37.503 	Pos: 283
# Bought at 20190124 with price = 38.604 	Pos: 275
# Sold at 20190128 with price = 33.814 	Pos: 275
# Bought at 20190131 with price = 35.888 	Pos: 259
# Sold at 20190207 with price = 35.941 	Pos: 259
# Bought at 20190212 with price = 37.841 	Pos: 245
# Sold at 20190221 with price = 39.204 	Pos: 245
# Bought at 20190305 with price = 38.824 	Pos: 247
# Sold at 20190306 with price = 37.565 	Pos: 247
# Bought at 20190311 with price = 40.34 	Pos: 230
# Sold at 20190325 with price = 44.624 	Pos: 230
# Bought at 20190329 with price = 45.566 	Pos: 225
# Sold at 20190409 with price = 47.042 	Pos: 225
# Bought at 20190410 with price = 47.782 	Pos: 221
# Sold at 20190411 with price = 48.005 	Pos: 221
# Bought at 20190423 with price = 47.505 	Pos: 223
# Sold at 20190425 with price = 44.928 	Pos: 223
# Bought at 20190502 with price = 45.63 	Pos: 220
# Sold at 20190506 with price = 44.229 	Pos: 220
# Bought at 20190604 with price = 36.334 	Pos: 268
# Sold at 20190612 with price = 36.611 	Pos: 268
# Bought at 20190613 with price = 35.968 	Pos: 272
# Sold at 20190614 with price = 35.984 	Pos: 272
# Bought at 20190618 with price = 38.404 	Pos: 255
# Sold at 20190624 with price = 38.045 	Pos: 255
# Bought at 20190626 with price = 40.497 	Pos: 239
# Sold at 20190702 with price = 40.612 	Pos: 239
# Bought at 20190710 with price = 40.57 	Pos: 239
# Sold at 20190719 with price = 42.139 	Pos: 239
# Bought at 20190722 with price = 43.035 	Pos: 234
# Sold at 20190725 with price = 43.428 	Pos: 234
# Bought at 20190726 with price = 43.505 	Pos: 233
# Sold at 20190729 with price = 43.048 	Pos: 233
# Bought at 20190808 with price = 38.98 	Pos: 257
# Sold at 20190809 with price = 37.853 	Pos: 257
# Bought at 20190813 with price = 37.958 	Pos: 256
# Sold at 20190814 with price = 37.608 	Pos: 256
# Bought at 20190816 with price = 40.85 	Pos: 236
# Sold at 20190823 with price = 41.22 	Pos: 236
# Bought at 20190829 with price = 42.071 	Pos: 231
# Sold at 20190903 with price = 41.509 	Pos: 231
# Bought at 20190904 with price = 43.07 	Pos: 222
# Sold at 20190913 with price = 44.579 	Pos: 222
# Bought at 20190925 with price = 44.309 	Pos: 223
# Sold at 20190927 with price = 43.052 	Pos: 223
# Bought at 20191003 with price = 45.198 	Pos: 212
# Sold at 20191008 with price = 44.928 	Pos: 212
# Bought at 20191011 with price = 46.225 	Pos: 206
# Sold at 20191018 with price = 48.072 	Pos: 206
# Bought at 20191024 with price = 49.854 	Pos: 199
# Sold at 20191030 with price = 50.366 	Pos: 199
# Bought at 20191104 with price = 52.442 	Pos: 190
# Sold at 20191106 with price = 52.596 	Pos: 190
# Bought at 20191118 with price = 52.579 	Pos: 190
# Sold at 20191119 with price = 51.594 	Pos: 190
# Bought at 20191125 with price = 54.936 	Pos: 179
# Sold at 20191126 with price = 54.519 	Pos: 179
# Bought at 20191211 with price = 53.902 	Pos: 180
# Sold at 20191218 with price = 57.568 	Pos: 180
# Bought at 20191219 with price = 59.374 	Pos: 175
# Sold at 20191223 with price = 59.391 	Pos: 175
# ======= from 20190101 to 20191231 =========
# If buy at 20190108 with price = 35.246
# and do nothing
# Current Profit: 6312.138690999998
# Current Profit with model: 399.22057200003655
# CAGR Performance: -59.13%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - NVDA from 20200101
# Transforming Data... - NVDA from 20200101
# Predicting... - NVDA from 20200101
# Converting... - NVDA from 20200101
# Backtesting... - NVDA from 20200101
# Clearing trade_record...
# Start Iteration... - NVDA from 20200101
# Start Backtesting...
# Bought at 20200109 with price = 61.666 	Pos: 162
# Sold at 20200114 with price = 61.781 	Pos: 162
# Bought at 20200205 with price = 62.866 	Pos: 159
# Sold at 20200221 with price = 67.369 	Pos: 159
# Bought at 20200228 with price = 69.08 	Pos: 155
# Sold at 20200303 with price = 67.412 	Pos: 155
# Bought at 20200304 with price = 68.98 	Pos: 151
# Sold at 20200306 with price = 59.85 	Pos: 151
# Bought at 20200323 with price = 57.13 	Pos: 158
# Sold at 20200401 with price = 60.936 	Pos: 158
# Bought at 20200406 with price = 69.18 	Pos: 139
# Sold at 20200409 with price = 65.0 	Pos: 139
# Bought at 20200414 with price = 69.154 	Pos: 130
# Sold at 20200421 with price = 69.162 	Pos: 130
# Bought at 20200424 with price = 73.593 	Pos: 122
# Sold at 20200428 with price = 74.036 	Pos: 122
# Bought at 20200429 with price = 73.918 	Pos: 122
# Sold at 20200430 with price = 70.938 	Pos: 122
# Bought at 20200506 with price = 75.688 	Pos: 115
# Sold at 20200513 with price = 78.253 	Pos: 115
# Bought at 20200514 with price = 78.735 	Pos: 114
# Sold at 20200526 with price = 86.069 	Pos: 114
# Bought at 20200602 with price = 88.038 	Pos: 111
# Sold at 20200604 with price = 87.801 	Pos: 111
# Bought at 20200605 with price = 88.628 	Pos: 110
# Sold at 20200608 with price = 87.857 	Pos: 110
# Bought at 20200609 with price = 91.526 	Pos: 105
# Sold at 20200611 with price = 91.474 	Pos: 105
# Bought at 20200615 with price = 92.098 	Pos: 105
# Sold at 20200616 with price = 90.986 	Pos: 105
# Bought at 20200617 with price = 92.118 	Pos: 103
# Sold at 20200624 with price = 93.406 	Pos: 103
# Bought at 20200625 with price = 94.845 	Pos: 102
# Sold at 20200626 with price = 91.546 	Pos: 102
# Bought at 20200630 with price = 95.053 	Pos: 98
# Sold at 20200713 with price = 100.59 	Pos: 98
# Bought at 20200720 with price = 104.96 	Pos: 94
# Sold at 20200721 with price = 103.51 	Pos: 94
# Bought at 20200722 with price = 104.33 	Pos: 93
# Sold at 20200723 with price = 98.586 	Pos: 93
# Bought at 20200727 with price = 103.58 	Pos: 88
# Sold at 20200728 with price = 103.74 	Pos: 88
# Bought at 20200729 with price = 103.59 	Pos: 88
# Sold at 20200807 with price = 113.16 	Pos: 88
# Bought at 20200812 with price = 115.27 	Pos: 86
# Sold at 20200827 with price = 126.54 	Pos: 86
# Bought at 20200828 with price = 131.61 	Pos: 83
# Sold at 20200903 with price = 127.67 	Pos: 83
# Bought at 20200914 with price = 132.63 	Pos: 80
# Sold at 20200916 with price = 121.16 	Pos: 80
# Bought at 20200925 with price = 130.23 	Pos: 74
# Sold at 20201002 with price = 132.19 	Pos: 74
# Bought at 20201005 with price = 138.12 	Pos: 71
# Sold at 20201008 with price = 137.49 	Pos: 71
# Bought at 20201104 with price = 141.44 	Pos: 69
# Sold at 20201109 with price = 135.89 	Pos: 69
# Bought at 20201202 with price = 135.74 	Pos: 69
# Sold at 20201203 with price = 134.35 	Pos: 69
# ======= from 20200101 to 20201231 =========
# If buy at 20200108 with price = 60.8
# and do nothing
# Current Profit: 11545.534399999997
# Current Profit with model: -701.7070514999614
# CAGR Performance: -122.47%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - NVDA from 20210101
# Transforming Data... - NVDA from 20210101
# Predicting... - NVDA from 20210101
# Converting... - NVDA from 20210101
# Backtesting... - NVDA from 20210101
# Clearing trade_record...
# Start Iteration... - NVDA from 20210101
# Start Backtesting...
# Bought at 20210111 with price = 137.39 	Pos: 72
# Sold at 20210114 with price = 132.15 	Pos: 72
# Bought at 20210121 with price = 137.26 	Pos: 70
# Sold at 20210126 with price = 132.17 	Pos: 70
# Bought at 20210202 with price = 136.22 	Pos: 67
# Sold at 20210217 with price = 147.13 	Pos: 67
# Bought at 20210311 with price = 126.39 	Pos: 78
# Sold at 20210318 with price = 127.41 	Pos: 78
# Bought at 20210331 with price = 135.63 	Pos: 73
# Sold at 20210419 with price = 153.11 	Pos: 73
# Bought at 20210426 with price = 155.66 	Pos: 72
# Sold at 20210428 with price = 153.88 	Pos: 72
# Bought at 20210517 with price = 142.57 	Pos: 78
# Sold at 20210518 with price = 135.57 	Pos: 78
# Bought at 20210520 with price = 151.53 	Pos: 69
# Sold at 20210527 with price = 154.89 	Pos: 69
# Bought at 20210528 with price = 162.58 	Pos: 66
# Sold at 20210609 with price = 173.42 	Pos: 66
# Bought at 20210611 with price = 178.98 	Pos: 64
# Sold at 20210707 with price = 198.47 	Pos: 64
# Bought at 20210721 with price = 196.34 	Pos: 65
# Sold at 20210726 with price = 192.57 	Pos: 65
# Bought at 20210729 with price = 194.1 	Pos: 64
# Sold at 20210730 with price = 196.92 	Pos: 64
# Bought at 20210802 with price = 197.32 	Pos: 64
# Sold at 20210809 with price = 203.13 	Pos: 64
# Bought at 20210820 with price = 209.6 	Pos: 62
# Sold at 20210831 with price = 224.78 	Pos: 62
# Bought at 20210923 with price = 220.63 	Pos: 63
# Sold at 20210927 with price = 212.07 	Pos: 63
# Bought at 20211006 with price = 210.85 	Pos: 63
# Sold at 20211011 with price = 208.21 	Pos: 63
# Bought at 20211014 with price = 218.03 	Pos: 60
# Sold at 20211020 with price = 220.9 	Pos: 60
# Bought at 20211021 with price = 228.16 	Pos: 58
# Sold at 20211110 with price = 304.59 	Pos: 58
# Bought at 20211119 with price = 335.07 	Pos: 53
# Sold at 20211122 with price = 315.26 	Pos: 53
# Bought at 20211207 with price = 319.94 	Pos: 52
# Sold at 20211208 with price = 317.29 	Pos: 52
# Bought at 20211223 with price = 296.55 	Pos: 55
# Sold at 20211228 with price = 302.67 	Pos: 55
# ======= from 20210101 to 20211231 =========
# If buy at 20210108 with price = 134.05
# and do nothing
# Current Profit: 12030.400150000001
# Current Profit with model: 6908.3575250000285
# CAGR Performance: -51.22%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Runninng stock: FB
# entire dataset 2495
# data_1 length 2495
# FB Data loaded...
# Getting Data... - FB from 20120101
# Transforming Data... - FB from 20120101
# Predicting... - FB from 20120101
# Converting... - FB from 20120101
# Backtesting... - FB from 20120101
# Clearing trade_record...
# Start Iteration... - FB from 20120101
# Start Backtesting...
# Bought at 20120608 with price = 27.18 	Pos: 367
# Sold at 20120625 with price = 32.69 	Pos: 367
# Bought at 20120626 with price = 32.46 	Pos: 369
# Sold at 20120627 with price = 31.96 	Pos: 369
# Bought at 20120705 with price = 31.44 	Pos: 375
# Sold at 20120710 with price = 31.48 	Pos: 375
# Bought at 20120723 with price = 28.82 	Pos: 409
# Sold at 20120724 with price = 28.39 	Pos: 409
# Bought at 20120725 with price = 27.75 	Pos: 418
# Sold at 20120726 with price = 23.19 	Pos: 418
# Bought at 20120806 with price = 22.2 	Pos: 437
# Sold at 20120807 with price = 20.71 	Pos: 437
# Bought at 20120810 with price = 22.15 	Pos: 408
# Sold at 20120814 with price = 20.64 	Pos: 408
# Bought at 20120906 with price = 19.1 	Pos: 441
# Sold at 20120924 with price = 21.2 	Pos: 441
# Bought at 20120928 with price = 22.08 	Pos: 423
# Sold at 20121005 with price = 20.4 	Pos: 423
# Bought at 20121017 with price = 19.7 	Pos: 437
# Sold at 20121018 with price = 19.0 	Pos: 437
# Bought at 20121023 with price = 24.13 	Pos: 344
# Sold at 20121031 with price = 21.08 	Pos: 344
# Bought at 20121106 with price = 20.85 	Pos: 347
# Sold at 20121107 with price = 20.52 	Pos: 347
# Bought at 20121114 with price = 22.34 	Pos: 319
# Sold at 20121206 with price = 27.07 	Pos: 319
# Bought at 20121207 with price = 27.17 	Pos: 317
# Sold at 20121214 with price = 26.77 	Pos: 317
# Bought at 20121218 with price = 27.83 	Pos: 305
# Sold at 20121221 with price = 26.5 	Pos: 305
# ======= from 20120101 to 20121231 =========
# If buy at 20120524 with price = 32.9
# and do nothing
# Current Profit: -2035.0843499999983
# Current Profit with model: -1915.3361799999902
# CAGR Performance: 1.2%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - FB from 20130101
# Transforming Data... - FB from 20130101
# Predicting... - FB from 20130101
# Converting... - FB from 20130101
# Backtesting... - FB from 20130101
# Clearing trade_record...
# Start Iteration... - FB from 20130101
# Start Backtesting...
# Bought at 20130108 with price = 29.67 	Pos: 336
# Sold at 20130115 with price = 30.21 	Pos: 336
# Bought at 20130122 with price = 31.1 	Pos: 326
# Sold at 20130129 with price = 30.98 	Pos: 326
# Bought at 20130214 with price = 28.51 	Pos: 354
# Sold at 20130221 with price = 27.62 	Pos: 354
# Bought at 20130301 with price = 27.76 	Pos: 352
# Sold at 20130306 with price = 27.57 	Pos: 352
# Bought at 20130307 with price = 28.42 	Pos: 341
# Sold at 20130312 with price = 27.62 	Pos: 341
# Bought at 20130327 with price = 26.09 	Pos: 361
# Sold at 20130402 with price = 25.83 	Pos: 361
# Bought at 20130403 with price = 26.62 	Pos: 350
# Sold at 20130415 with price = 26.81 	Pos: 350
# Bought at 20130424 with price = 26.06 	Pos: 360
# Sold at 20130506 with price = 27.51 	Pos: 360
# Bought at 20130514 with price = 26.92 	Pos: 367
# Sold at 20130515 with price = 26.48 	Pos: 367
# Bought at 20130610 with price = 24.03 	Pos: 404
# Sold at 20130613 with price = 23.56 	Pos: 404
# Bought at 20130617 with price = 24.09 	Pos: 395
# Sold at 20130620 with price = 24.59 	Pos: 395
# Bought at 20130621 with price = 23.95 	Pos: 405
# Sold at 20130624 with price = 24.14 	Pos: 405
# Bought at 20130627 with price = 24.68 	Pos: 396
# Sold at 20130702 with price = 24.22 	Pos: 396
# Bought at 20130708 with price = 25.08 	Pos: 382
# Sold at 20130718 with price = 25.82 	Pos: 382
# Bought at 20130724 with price = 33.54 	Pos: 294
# Sold at 20130808 with price = 38.59 	Pos: 294
# Bought at 20130819 with price = 38.35 	Pos: 295
# Sold at 20130830 with price = 41.84 	Pos: 295
# Bought at 20130903 with price = 42.01 	Pos: 294
# Sold at 20130904 with price = 41.79 	Pos: 294
# Bought at 20130905 with price = 43.09 	Pos: 284
# Sold at 20130912 with price = 45.04 	Pos: 284
# Bought at 20130919 with price = 46.32 	Pos: 276
# Sold at 20130930 with price = 49.97 	Pos: 276
# Bought at 20131016 with price = 51.12 	Pos: 270
# Sold at 20131022 with price = 51.75 	Pos: 270
# Bought at 20131113 with price = 48.7 	Pos: 286
# Sold at 20131118 with price = 46.26 	Pos: 286
# Bought at 20131204 with price = 48.15 	Pos: 275
# Sold at 20131206 with price = 48.09 	Pos: 275
# Bought at 20131210 with price = 50.56 	Pos: 261
# Sold at 20131211 with price = 51.04 	Pos: 261
# Bought at 20131212 with price = 51.66 	Pos: 258
# Sold at 20131219 with price = 54.93 	Pos: 258
# Bought at 20131223 with price = 58.27 	Pos: 243
# Sold at 20131226 with price = 57.48 	Pos: 243
# ======= from 20130101 to 20131231 =========
# If buy at 20130108 with price = 29.67
# and do nothing
# Current Profit: 8210.21544
# Current Profit with model: 3971.065615000023
# CAGR Performance: -42.39%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - FB from 20140101
# Transforming Data... - FB from 20140101
# Predicting... - FB from 20140101
# Converting... - FB from 20140101
# Backtesting... - FB from 20140101
# Clearing trade_record...
# Start Iteration... - FB from 20140101
# Start Backtesting...
# Bought at 20140108 with price = 58.65 	Pos: 170
# Sold at 20140113 with price = 56.46 	Pos: 170
# Bought at 20140114 with price = 57.98 	Pos: 165
# Sold at 20140116 with price = 57.3 	Pos: 165
# Bought at 20140121 with price = 58.85 	Pos: 161
# Sold at 20140122 with price = 56.38 	Pos: 161
# Bought at 20140130 with price = 60.25 	Pos: 150
# Sold at 20140205 with price = 61.46 	Pos: 150
# Bought at 20140206 with price = 62.27 	Pos: 148
# Sold at 20140226 with price = 69.36 	Pos: 148
# Bought at 20140305 with price = 71.88 	Pos: 143
# Sold at 20140311 with price = 69.86 	Pos: 143
# Bought at 20140401 with price = 63.21 	Pos: 158
# Sold at 20140403 with price = 59.95 	Pos: 158
# Bought at 20140409 with price = 63.08 	Pos: 150
# Sold at 20140414 with price = 59.29 	Pos: 150
# Bought at 20140421 with price = 62.65 	Pos: 141
# Sold at 20140424 with price = 59.97 	Pos: 141
# Bought at 20140430 with price = 60.43 	Pos: 140
# Sold at 20140506 with price = 58.77 	Pos: 140
# Bought at 20140512 with price = 59.66 	Pos: 138
# Sold at 20140515 with price = 58.31 	Pos: 138
# Bought at 20140519 with price = 59.5 	Pos: 135
# Sold at 20140520 with price = 58.55 	Pos: 135
# Bought at 20140521 with price = 60.94 	Pos: 130
# Sold at 20140602 with price = 62.62 	Pos: 130
# Bought at 20140610 with price = 65.32 	Pos: 124
# Sold at 20140616 with price = 64.1 	Pos: 124
# Bought at 20140618 with price = 65.49 	Pos: 121
# Sold at 20140619 with price = 64.46 	Pos: 121
# Bought at 20140623 with price = 65.36 	Pos: 120
# Sold at 20140702 with price = 66.86 	Pos: 120
# Bought at 20140711 with price = 67.13 	Pos: 119
# Sold at 20140717 with price = 66.8 	Pos: 119
# Bought at 20140718 with price = 68.81 	Pos: 115
# Sold at 20140730 with price = 74.0 	Pos: 115
# Bought at 20140807 with price = 73.4 	Pos: 116
# Sold at 20140808 with price = 73.47 	Pos: 116
# Bought at 20140813 with price = 73.97 	Pos: 115
# Sold at 20140815 with price = 74.0 	Pos: 115
# Bought at 20140818 with price = 74.81 	Pos: 114
# Sold at 20140820 with price = 74.93 	Pos: 114
# Bought at 20140826 with price = 75.27 	Pos: 113
# Sold at 20140827 with price = 74.0 	Pos: 113
# Bought at 20140902 with price = 77.14 	Pos: 109
# Sold at 20140903 with price = 75.9 	Pos: 109
# Bought at 20140904 with price = 76.1 	Pos: 108
# Sold at 20140909 with price = 76.53 	Pos: 108
# Bought at 20140910 with price = 77.13 	Pos: 107
# Sold at 20140912 with price = 77.15 	Pos: 107
# Bought at 20140919 with price = 77.0 	Pos: 107
# Sold at 20140925 with price = 77.59 	Pos: 107
# Bought at 20140926 with price = 78.12 	Pos: 107
# Sold at 20140930 with price = 78.78 	Pos: 107
# Bought at 20141017 with price = 75.6 	Pos: 111
# Sold at 20141028 with price = 75.45 	Pos: 111
# Bought at 20141125 with price = 75.53 	Pos: 111
# Sold at 20141201 with price = 75.33 	Pos: 111
# Bought at 20141208 with price = 75.2 	Pos: 111
# Sold at 20141215 with price = 76.18 	Pos: 111
# Bought at 20141218 with price = 78.75 	Pos: 107
# Sold at 20141226 with price = 80.49 	Pos: 107
# ======= from 20140101 to 20141231 =========
# If buy at 20140108 with price = 58.65
# and do nothing
# Current Profit: 3544.6147500000006
# Current Profit with model: -1350.3136749999649
# CAGR Performance: -48.95%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - FB from 20150101
# Transforming Data... - FB from 20150101
# Predicting... - FB from 20150101
# Converting... - FB from 20150101
# Backtesting... - FB from 20150101
# Clearing trade_record...
# Start Iteration... - FB from 20150101
# Start Backtesting...
# Bought at 20150108 with price = 78.2 	Pos: 127
# Sold at 20150112 with price = 77.23 	Pos: 127
# Bought at 20150121 with price = 77.17 	Pos: 127
# Sold at 20150127 with price = 76.9 	Pos: 127
# Bought at 20150211 with price = 76.84 	Pos: 127
# Sold at 20150217 with price = 75.94 	Pos: 127
# Bought at 20150218 with price = 76.99 	Pos: 125
# Sold at 20150227 with price = 79.0 	Pos: 125
# Bought at 20150302 with price = 79.61 	Pos: 124
# Sold at 20150303 with price = 79.3 	Pos: 124
# Bought at 20150304 with price = 81.23 	Pos: 121
# Sold at 20150309 with price = 78.5 	Pos: 121
# Bought at 20150317 with price = 79.25 	Pos: 120
# Sold at 20150325 with price = 82.72 	Pos: 120
# Bought at 20150408 with price = 82.5 	Pos: 120
# Sold at 20150409 with price = 82.2 	Pos: 120
# Bought at 20150413 with price = 83.17 	Pos: 119
# Sold at 20150415 with price = 82.46 	Pos: 119
# Bought at 20150420 with price = 84.0 	Pos: 116
# Sold at 20150423 with price = 82.77 	Pos: 116
# Bought at 20150514 with price = 81.41 	Pos: 118
# Sold at 20150520 with price = 80.19 	Pos: 118
# Bought at 20150527 with price = 80.25 	Pos: 118
# Sold at 20150528 with price = 79.94 	Pos: 118
# Bought at 20150602 with price = 81.35 	Pos: 116
# Sold at 20150608 with price = 80.63 	Pos: 116
# Bought at 20150610 with price = 82.31 	Pos: 113
# Sold at 20150615 with price = 80.82 	Pos: 113
# Bought at 20150617 with price = 81.58 	Pos: 112
# Sold at 20150629 with price = 86.6 	Pos: 112
# Bought at 20150706 with price = 87.8 	Pos: 110
# Sold at 20150707 with price = 86.29 	Pos: 110
# Bought at 20150710 with price = 88.68 	Pos: 107
# Sold at 20150723 with price = 97.35 	Pos: 107
# Bought at 20150805 with price = 97.18 	Pos: 107
# Sold at 20150806 with price = 95.38 	Pos: 107
# Bought at 20150818 with price = 94.63 	Pos: 108
# Sold at 20150820 with price = 87.52 	Pos: 108
# Bought at 20150827 with price = 89.88 	Pos: 105
# Sold at 20150901 with price = 88.81 	Pos: 105
# Bought at 20150902 with price = 89.76 	Pos: 104
# Sold at 20150903 with price = 87.2 	Pos: 104
# Bought at 20150908 with price = 90.78 	Pos: 100
# Sold at 20150922 with price = 93.4 	Pos: 100
# Bought at 20151002 with price = 92.94 	Pos: 100
# Sold at 20151008 with price = 92.9 	Pos: 100
# Bought at 20151012 with price = 93.66 	Pos: 99
# Sold at 20151021 with price = 97.79 	Pos: 99
# Bought at 20151022 with price = 101.91 	Pos: 95
# Sold at 20151030 with price = 102.46 	Pos: 95
# Bought at 20151105 with price = 108.04 	Pos: 90
# Sold at 20151109 with price = 105.96 	Pos: 90
# Bought at 20151110 with price = 108.27 	Pos: 88
# Sold at 20151111 with price = 108.48 	Pos: 88
# Bought at 20151118 with price = 107.36 	Pos: 89
# Sold at 20151119 with price = 106.84 	Pos: 89
# Bought at 20151120 with price = 107.19 	Pos: 89
# Sold at 20151123 with price = 106.0 	Pos: 89
# Bought at 20151216 with price = 107.49 	Pos: 87
# Sold at 20151217 with price = 106.08 	Pos: 87
# Bought at 20151229 with price = 107.0 	Pos: 86
# Sold at 20151230 with price = 106.0 	Pos: 86
# ======= from 20150101 to 20151231 =========
# If buy at 20150108 with price = 78.2
# and do nothing
# Current Profit: 3525.6343000000015
# Current Profit with model: -791.5327199999574
# CAGR Performance: -43.17%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - FB from 20160101
# Transforming Data... - FB from 20160101
# Predicting... - FB from 20160101
# Converting... - FB from 20160101
# Backtesting... - FB from 20160101
# Clearing trade_record...
# Start Iteration... - FB from 20160101
# Start Backtesting...
# Bought at 20160122 with price = 98.72 	Pos: 101
# Sold at 20160127 with price = 107.2 	Pos: 101
# Bought at 20160128 with price = 108.99 	Pos: 99
# Sold at 20160204 with price = 109.51 	Pos: 99
# Bought at 20160211 with price = 103.74 	Pos: 104
# Sold at 20160304 with price = 108.07 	Pos: 104
# Bought at 20160311 with price = 109.28 	Pos: 103
# Sold at 20160404 with price = 112.11 	Pos: 103
# Bought at 20160407 with price = 114.25 	Pos: 101
# Sold at 20160408 with price = 110.7 	Pos: 101
# Bought at 20160419 with price = 112.43 	Pos: 99
# Sold at 20160422 with price = 109.87 	Pos: 99
# Bought at 20160428 with price = 116.82 	Pos: 93
# Sold at 20160513 with price = 119.38 	Pos: 93
# Bought at 20160524 with price = 118.13 	Pos: 94
# Sold at 20160601 with price = 118.69 	Pos: 94
# Bought at 20160621 with price = 114.65 	Pos: 97
# Sold at 20160622 with price = 114.37 	Pos: 97
# Bought at 20160623 with price = 111.01 	Pos: 100
# Sold at 20160624 with price = 111.57 	Pos: 100
# Bought at 20160629 with price = 114.67 	Pos: 98
# Sold at 20160713 with price = 117.5 	Pos: 98
# Bought at 20160718 with price = 118.99 	Pos: 96
# Sold at 20160726 with price = 122.42 	Pos: 96
# Bought at 20160727 with price = 127.52 	Pos: 92
# Sold at 20160802 with price = 123.09 	Pos: 92
# Bought at 20160804 with price = 124.98 	Pos: 91
# Sold at 20160811 with price = 124.7 	Pos: 91
# Bought at 20160822 with price = 124.51 	Pos: 91
# Sold at 20160824 with price = 123.12 	Pos: 91
# Bought at 20160826 with price = 124.35 	Pos: 90
# Sold at 20160909 with price = 125.96 	Pos: 90
# Bought at 20160916 with price = 129.91 	Pos: 87
# Sold at 20160919 with price = 128.65 	Pos: 87
# Bought at 20160921 with price = 130.5 	Pos: 86
# Sold at 20160923 with price = 127.37 	Pos: 86
# Bought at 20161010 with price = 130.23 	Pos: 84
# Sold at 20161011 with price = 129.01 	Pos: 84
# Bought at 20161019 with price = 130.07 	Pos: 83
# ...
# Runninng stock: MAR
# entire dataset 5609
# data_1 length 5609
# MAR Data loaded...
# Getting Data... - MAR from 20120101
# Transforming Data... - MAR from 20120101
# Predicting... - MAR from 20120101
# Converting... - MAR from 20120101
# Backtesting... - MAR from 20120101
# Clearing trade_record...
# Start Iteration... - MAR from 20120101
# Start Backtesting...
# Bought at 20120109 with price = 29.679 	Pos: 336
# Sold at 20120126 with price = 31.067 	Pos: 336
# Bought at 20120201 with price = 31.032 	Pos: 336
# Sold at 20120209 with price = 32.108 	Pos: 336
# Bought at 20120227 with price = 31.318 	Pos: 344
# Sold at 20120319 with price = 34.015 	Pos: 344
# Bought at 20120326 with price = 34.826 	Pos: 336
# Sold at 20120328 with price = 33.981 	Pos: 336
# Bought at 20120403 with price = 34.058 	Pos: 335
# Sold at 20120404 with price = 33.747 	Pos: 335
# Bought at 20120412 with price = 33.711 	Pos: 335
# Sold at 20120416 with price = 34.024 	Pos: 335
# Bought at 20120417 with price = 33.944 	Pos: 335
# Sold at 20120424 with price = 34.854 	Pos: 335
# Bought at 20120425 with price = 35.267 	Pos: 331
# Sold at 20120504 with price = 35.202 	Pos: 331
# Bought at 20120510 with price = 35.114 	Pos: 332
# Sold at 20120514 with price = 34.652 	Pos: 332
# Bought at 20120515 with price = 35.239 	Pos: 326
# Sold at 20120516 with price = 34.781 	Pos: 326
# Bought at 20120523 with price = 34.374 	Pos: 329
# Sold at 20120601 with price = 33.043 	Pos: 329
# Bought at 20120606 with price = 34.312 	Pos: 317
# Sold at 20120611 with price = 33.278 	Pos: 317
# Bought at 20120614 with price = 33.869 	Pos: 311
# Sold at 20120625 with price = 34.007 	Pos: 311
# Bought at 20120629 with price = 35.239 	Pos: 300
# Sold at 20120709 with price = 35.41 	Pos: 300
# Bought at 20120718 with price = 33.144 	Pos: 320
# Sold at 20120723 with price = 32.137 	Pos: 320
# Bought at 20120727 with price = 33.052 	Pos: 311
# Sold at 20120801 with price = 32.404 	Pos: 311
# Bought at 20120803 with price = 33.833 	Pos: 297
# Sold at 20120809 with price = 33.441 	Pos: 297
# Bought at 20120816 with price = 34.058 	Pos: 292
# Sold at 20120822 with price = 33.573 	Pos: 292
# Bought at 20120827 with price = 33.537 	Pos: 292
# Sold at 20120905 with price = 34.069 	Pos: 292
# Bought at 20120906 with price = 35.11 	Pos: 283
# Sold at 20120920 with price = 36.967 	Pos: 283
# Bought at 20121015 with price = 35.027 	Pos: 298
# Sold at 20121019 with price = 33.87 	Pos: 298
# Bought at 20121101 with price = 33.563 	Pos: 301
# Sold at 20121102 with price = 32.961 	Pos: 301
# Bought at 20121119 with price = 32.049 	Pos: 309
# Sold at 20121126 with price = 31.306 	Pos: 309
# Bought at 20121128 with price = 32.147 	Pos: 300
# Sold at 20121204 with price = 32.26 	Pos: 300
# Bought at 20121211 with price = 32.602 	Pos: 297
# Sold at 20121213 with price = 32.129 	Pos: 297
# Bought at 20121214 with price = 32.799 	Pos: 291
# Sold at 20121224 with price = 33.652 	Pos: 291
# ======= from 20120101 to 20121231 =========
# If buy at 20120109 with price = 29.679
# and do nothing
# Current Profit: 1074.5819280000014
# Current Profit with model: -208.27767099997436
# CAGR Performance: -12.83%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - MAR from 20130101
# Transforming Data... - MAR from 20130101
# Predicting... - MAR from 20130101
# Converting... - MAR from 20130101
# Backtesting... - MAR from 20130101
# Clearing trade_record...
# Start Iteration... - MAR from 20130101
# Start Backtesting...
# Bought at 20130108 with price = 35.309 	Pos: 283
# Sold at 20130109 with price = 35.5 	Pos: 283
# Bought at 20130115 with price = 35.29 	Pos: 284
# Sold at 20130116 with price = 35.282 	Pos: 284
# Bought at 20130117 with price = 35.672 	Pos: 281
# Sold at 20130124 with price = 35.472 	Pos: 281
# Bought at 20130125 with price = 35.789 	Pos: 278
# Sold at 20130204 with price = 36.252 	Pos: 278
# Bought at 20130206 with price = 36.733 	Pos: 274
# Sold at 20130219 with price = 36.116 	Pos: 274
# Bought at 20130227 with price = 35.757 	Pos: 276
# Sold at 20130306 with price = 35.893 	Pos: 276
# Bought at 20130308 with price = 36.637 	Pos: 270
# Sold at 20130318 with price = 36.358 	Pos: 270
# Bought at 20130322 with price = 36.358 	Pos: 270
# Sold at 20130325 with price = 36.292 	Pos: 270
# Bought at 20130326 with price = 37.302 	Pos: 263
# Sold at 20130403 with price = 37.247 	Pos: 263
# Bought at 20130409 with price = 37.863 	Pos: 258
# Sold at 20130415 with price = 37.445 	Pos: 258
# Bought at 20130423 with price = 38.155 	Pos: 253
# Sold at 20130426 with price = 37.72 	Pos: 253
# Bought at 20130430 with price = 38.594 	Pos: 247
# Sold at 20130509 with price = 39.402 	Pos: 247
# Bought at 20130510 with price = 39.92 	Pos: 244
# Sold at 20130513 with price = 39.674 	Pos: 244
# Bought at 20130514 with price = 39.911 	Pos: 242
# Sold at 20130516 with price = 39.374 	Pos: 242
# Bought at 20130528 with price = 39.154 	Pos: 243
# Sold at 20130529 with price = 38.762 	Pos: 243
# Bought at 20130607 with price = 38.053 	Pos: 247
# Sold at 20130611 with price = 37.53 	Pos: 247
# Bought at 20130626 with price = 36.253 	Pos: 256
# Sold at 20130712 with price = 38.088 	Pos: 256
# Bought at 20130718 with price = 38.278 	Pos: 254
# Sold at 20130719 with price = 37.894 	Pos: 254
# Bought at 20130726 with price = 37.484 	Pos: 257
# Sold at 20130729 with price = 37.603 	Pos: 257
# Bought at 20130730 with price = 37.847 	Pos: 255
# Sold at 20130806 with price = 37.977 	Pos: 255
# Bought at 20130814 with price = 37.394 	Pos: 259
# Sold at 20130815 with price = 37.22 	Pos: 259
# Bought at 20130822 with price = 37.973 	Pos: 253
# Sold at 20130827 with price = 36.975 	Pos: 253
# Bought at 20130904 with price = 37.477 	Pos: 250
# Sold at 20130920 with price = 39.557 	Pos: 250
# Bought at 20131004 with price = 38.668 	Pos: 255
# Sold at 20131007 with price = 38.487 	Pos: 255
# Bought at 20131011 with price = 38.487 	Pos: 255
# Sold at 20131028 with price = 40.658 	Pos: 255
# Bought at 20131029 with price = 40.859 	Pos: 253
# Sold at 20131030 with price = 40.914 	Pos: 253
# Bought at 20131031 with price = 41.438 	Pos: 250
# Sold at 20131107 with price = 41.609 	Pos: 250
# Bought at 20131114 with price = 43.021 	Pos: 241
# Sold at 20131115 with price = 43.134 	Pos: 241
# Bought at 20131216 with price = 43.178 	Pos: 241
# Sold at 20131217 with price = 43.114 	Pos: 241
# Bought at 20131218 with price = 43.777 	Pos: 237
# Sold at 20131226 with price = 45.054 	Pos: 237
# ======= from 20130101 to 20131231 =========
# If buy at 20130108 with price = 35.309
# and do nothing
# Current Profit: 2755.668776499999
# Current Profit with model: 693.7177540000248
# CAGR Performance: -20.62%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - MAR from 20140101
# Transforming Data... - MAR from 20140101
# Predicting... - MAR from 20140101
# Converting... - MAR from 20140101
# Backtesting... - MAR from 20140101
# Clearing trade_record...
# Start Iteration... - MAR from 20140101
# Start Backtesting...
# Bought at 20140110 with price = 45.644 	Pos: 218
# Sold at 20140113 with price = 44.86 	Pos: 218
# Bought at 20140115 with price = 45.884 	Pos: 213
# Sold at 20140123 with price = 46.333 	Pos: 213
# Bought at 20140206 with price = 45.083 	Pos: 219
# Sold at 20140303 with price = 49.553 	Pos: 219
# Bought at 20140306 with price = 50.464 	Pos: 215
# Sold at 20140310 with price = 50.088 	Pos: 215
# Bought at 20140318 with price = 50.126 	Pos: 214
# Sold at 20140319 with price = 49.792 	Pos: 214
# Bought at 20140321 with price = 51.064 	Pos: 209
# Sold at 20140327 with price = 50.52 	Pos: 209
# Bought at 20140331 with price = 51.96 	Pos: 203
# Sold at 20140404 with price = 51.352 	Pos: 203
# Bought at 20140417 with price = 52.005 	Pos: 200
# Sold at 20140421 with price = 51.83 	Pos: 200
# Bought at 20140422 with price = 52.614 	Pos: 197
# Sold at 20140428 with price = 51.849 	Pos: 197
# Bought at 20140430 with price = 53.39 	Pos: 191
# Sold at 20140506 with price = 52.881 	Pos: 191
# Bought at 20140512 with price = 54.662 	Pos: 185
# Sold at 20140514 with price = 53.999 	Pos: 185
# Bought at 20140520 with price = 54.044 	Pos: 184
# Sold at 20140611 with price = 57.033 	Pos: 184
# Bought at 20140617 with price = 57.957 	Pos: 181
# Sold at 20140624 with price = 58.829 	Pos: 181
# Bought at 20140630 with price = 59.541 	Pos: 179
# Sold at 20140708 with price = 60.413 	Pos: 179
# Bought at 20140722 with price = 61.006 	Pos: 177
# Sold at 20140728 with price = 61.173 	Pos: 177
# Bought at 20140811 with price = 60.809 	Pos: 178
# Sold at 20140822 with price = 63.729 	Pos: 178
# Bought at 20140903 with price = 65.402 	Pos: 173
# Sold at 20140909 with price = 65.829 	Pos: 173
# Bought at 20140918 with price = 67.759 	Pos: 168
# Sold at 20140919 with price = 67.146 	Pos: 168
# Bought at 20141017 with price = 60.295 	Pos: 187
# Sold at 20141104 with price = 69.815 	Pos: 187
# Bought at 20141110 with price = 71.307 	Pos: 183
# Sold at 20141114 with price = 71.576 	Pos: 183
# Bought at 20141128 with price = 73.075 	Pos: 179
# Sold at 20141201 with price = 72.358 	Pos: 179
# ======= from 20140101 to 20141231 =========
# If buy at 20140108 with price = 45.185
# and do nothing
# Current Profit: 6193.836057499999
# Current Profit with model: 2965.9822630000253
# CAGR Performance: -32.28%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - MAR from 20150101
# Transforming Data... - MAR from 20150101
# Predicting... - MAR from 20150101
# Converting... - MAR from 20150101
# Backtesting... - MAR from 20150101
# Clearing trade_record...
# Start Iteration... - MAR from 20150101
# Start Backtesting...
# Bought at 20150108 with price = 73.344 	Pos: 136
# Sold at 20150114 with price = 71.39 	Pos: 136
# Bought at 20150121 with price = 71.212 	Pos: 136
# Sold at 20150128 with price = 71.491 	Pos: 136
# Bought at 20150203 with price = 70.59 	Pos: 138
# Sold at 20150206 with price = 68.252 	Pos: 138
# Bought at 20150210 with price = 71.798 	Pos: 131
# Sold at 20150224 with price = 76.723 	Pos: 131
# Bought at 20150226 with price = 77.739 	Pos: 129
# Sold at 20150304 with price = 77.721 	Pos: 129
# Bought at 20150312 with price = 77.042 	Pos: 130
# Sold at 20150313 with price = 76.965 	Pos: 130
# Bought at 20150316 with price = 77.825 	Pos: 128
# Sold at 20150324 with price = 76.388 	Pos: 128
# Bought at 20150330 with price = 75.856 	Pos: 129
# Sold at 20150331 with price = 74.941 	Pos: 129
# Bought at 20150408 with price = 74.661 	Pos: 129
# Sold at 20150413 with price = 74.522 	Pos: 129
# Bought at 20150420 with price = 74.841 	Pos: 129
# Sold at 20150428 with price = 76.91 	Pos: 129
# Bought at 20150429 with price = 76.799 	Pos: 129
# Sold at 20150430 with price = 75.256 	Pos: 129
# Bought at 20150508 with price = 74.791 	Pos: 129
# Sold at 20150512 with price = 73.663 	Pos: 129
# Bought at 20150514 with price = 75.517 	Pos: 126
# Sold at 20150521 with price = 75.245 	Pos: 126
# Bought at 20150603 with price = 73.808 	Pos: 128
# Sold at 20150604 with price = 73.238 	Pos: 128
# Bought at 20150617 with price = 72.424 	Pos: 130
# Sold at 20150624 with price = 71.553 	Pos: 130
# Bought at 20150707 with price = 69.903 	Pos: 133
# Sold at 20150708 with price = 70.409 	Pos: 133
# Bought at 20150710 with price = 71.852 	Pos: 130
# Sold at 20150721 with price = 71.645 	Pos: 130
# Bought at 20150729 with price = 71.14 	Pos: 131
# Sold at 20150730 with price = 69.125 	Pos: 131
# Bought at 20150810 with price = 67.423 	Pos: 134
# Sold at 20150820 with price = 65.044 	Pos: 134
# Bought at 20150826 with price = 66.171 	Pos: 132
# Sold at 20150901 with price = 66.051 	Pos: 132
# Bought at 20150902 with price = 66.773 	Pos: 130
# Sold at 20150915 with price = 68.117 	Pos: 130
# Bought at 20150916 with price = 68.446 	Pos: 129
# Sold at 20150917 with price = 66.557 	Pos: 129
# Bought at 20150930 with price = 64.235 	Pos: 134
# Sold at 20151014 with price = 70.152 	Pos: 134
# Bought at 20151020 with price = 70.306 	Pos: 133
# Sold at 20151021 with price = 69.993 	Pos: 133
# Bought at 20151022 with price = 71.327 	Pos: 131
# Sold at 20151103 with price = 72.174 	Pos: 131
# Bought at 20151104 with price = 72.382 	Pos: 130
# Sold at 20151105 with price = 72.1 	Pos: 130
# Bought at 20151201 with price = 67.933 	Pos: 138
# Sold at 20151203 with price = 66.436 	Pos: 138
# Bought at 20151222 with price = 64.379 	Pos: 142
# Sold at 20151230 with price = 64.079 	Pos: 142
# ======= from 20150101 to 20151231 =========
# If buy at 20150108 with price = 73.344
# and do nothing
# Current Profit: -1265.027392
# Current Profit with model: -850.4144634999666
# CAGR Performance: 4.15%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - MAR from 20160101
# Transforming Data... - MAR from 20160101
# Predicting... - MAR from 20160101
# Converting... - MAR from 20160101
# Backtesting... - MAR from 20160101
# Clearing trade_record...
# Start Iteration... - MAR from 20160101
# Start Backtesting...
# Bought at 20160112 with price = 60.157 	Pos: 166
# Sold at 20160113 with price = 56.745 	Pos: 166
# Bought at 20160121 with price = 58.98 	Pos: 159
# Sold at 20160127 with price = 57.746 	Pos: 159
# Bought at 20160201 with price = 56.926 	Pos: 161
# Sold at 20160202 with price = 55.756 	Pos: 161
# Bought at 20160204 with price = 57.188 	Pos: 157
# Sold at 20160205 with price = 56.16 	Pos: 157
# Bought at 20160209 with price = 58.083 	Pos: 152
# Sold at 20160303 with price = 65.085 	Pos: 152
# Bought at 20160304 with price = 64.809 	Pos: 152
# Sold at 20160308 with price = 65.027 	Pos: 152
# Bought at 20160314 with price = 66.275 	Pos: 149
# Sold at 20160322 with price = 66.74 	Pos: 149
# Bought at 20160328 with price = 67.145 	Pos: 148
# Sold at 20160401 with price = 63.505 	Pos: 148
# Bought at 20160408 with price = 63.146 	Pos: 149
# Sold at 20160418 with price = 63.969 	Pos: 149
# Bought at 20160421 with price = 64.546 	Pos: 147
# Sold at 20160422 with price = 63.146 	Pos: 147
# Bought at 20160427 with price = 63.978 	Pos: 145
# Sold at 20160504 with price = 65.699 	Pos: 145
# Bought at 20160510 with price = 66.523 	Pos: 143
# Sold at 20160511 with price = 65.596 	Pos: 143
# Bought at 20160525 with price = 62.886 	Pos: 149
# Sold at 20160607 with price = 64.122 	Pos: 149
# Bought at 20160617 with price = 63.818 	Pos: 150
# Sold at 20160624 with price = 60.16 	Pos: 150
# Bought at 20160630 with price = 63.086 	Pos: 143
# Sold at 20160714 with price = 66.916 	Pos: 143
# Bought at 20160722 with price = 67.392 	Pos: 142
# Sold at 20160727 with price = 66.062 	Pos: 142
# Bought at 20160728 with price = 67.771 	Pos: 138
# Sold at 20160801 with price = 67.648 	Pos: 138
# Bought at 20160803 with price = 67.742 	Pos: 138
# Sold at 20160809 with price = 68.448 	Pos: 138
# Bought at 20160815 with price = 69.312 	Pos: 136
# Sold at 20160818 with price = 69.017 	Pos: 136
# Bought at 20160819 with price = 69.994 	Pos: 134
# Sold at 20160822 with price = 69.778 	Pos: 134
# Bought at 20160915 with price = 65.634 	Pos: 142
# Sold at 20160919 with price = 65.48 	Pos: 142
# Bought at 20160920 with price = 66.613 	Pos: 140
# Sold at 20160923 with price = 66.04 	Pos: 140
# Bought at 20161003 with price = 64.255 	Pos: 143
# Sold at 20161004 with price = 64.14 	Pos: 143
# Bought at 20161005 with price = 64.275 	Pos: 143
# Sold at 20161006 with price = 64.41 	Pos: 143
# Bought at 20161014 with price = 64.275 	Pos: 143
# Sold at 20161017 with price = 64.629 	Pos: 143
# Bought at 20161018 with price = 64.847 	Pos: 142
# Sold at 20161020 with price = 63.998 	Pos: 142
# Bought at 20161028 with price = 64.629 	Pos: 141
# Sold at 20161118 with price = 73.808 	Pos: 141
# Bought at 20161129 with price = 75.755 	Pos: 137
# Sold at 20161130 with price = 75.179 	Pos: 137
# Bought at 20161201 with price = 75.859 	Pos: 136
# Sold at 20161202 with price = 77.134 	Pos: 136
# Bought at 20161205 with price = 77.604 	Pos: 135
# Sold at 20161209 with price = 79.931 	Pos: 135
# ======= from 20160101 to 20161231 =========
# If buy at 20160108 with price = 59.515
# and do nothing
# Current Profit: 3412.184497500002
# Current Profit with model: 803.8636370000295
# CAGR Performance: -26.08%
# Trade record exported.
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Getting Data... - MAR from 20170101
# Transforming Data... - MAR from 20170101
# Predicting... - MAR from 20170101
# Converting... - MAR from 20170101
# Backtesting... - MAR from 20170101
# Clearing trade_record...
